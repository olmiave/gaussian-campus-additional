# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision torchaudio
# !pip install plyfile
# !pip install tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Collecting plyfile
#   Downloading plyfile-1.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from plyfile) (1.26.4)
# Downloading plyfile-1.1-py3-none-any.whl (23 kB)
# Installing collected packages: plyfile
# Successfully installed plyfile-1.1
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)

# %% [markdown]
# # Cloning Gaussian Splatting Repository with Submodules

# %%
# cloning the repo and dependencies such as submodules
# %cd /content/drive/MyDrive/final_project_gsplat/
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# %cd /content/drive/MyDrive/final_project_gsplat/gaussian-splatting
# !pip install -q /content/drive/MyDrive/final_project_gsplat/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install -q /content/drive/MyDrive/final_project_gsplat/gaussian-splatting/submodules/simple-knn
# Out:
# /content/drive/MyDrive/final_project_gsplat
# fatal: destination path 'gaussian-splatting' already exists and is not an empty directory.
# /content/drive/MyDrive/final_project_gsplat/gaussian-splatting
#   Preparing metadata (setup.py) ... done
#   Building wheel for diff_gaussian_rasterization (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for simple_knn (setup.py) ... done

# %% [markdown]
# # Fetch Data

# %%
# !wget --no-check-certificate -O /content/drive/MyDrive/final_project_gsplat/hall_input.zip "https://alumniutdt-my.sharepoint.com/:u:/g/personal/micaela_oliva_mail_utdt_edu/EVAm3WMOA_BKuYQkDlXznLsBth0NNpoDvIQTISGUjy9l2A?download=1"

# !mkdir -p /content/drive/MyDrive/final_project_gsplat/gaussian-splatting/data/hall/input/

# !unzip /content/drive/MyDrive/final_project_gsplat/hall_input.zip -d /content/drive/MyDrive/final_project_gsplat/gaussian-splatting/data/hall/input/

# %% [markdown]
# # Installing Dependencies for COLMAP

# %%
# !sudo apt-get install -y \
    git \
    cmake \
    ninja-build \
    build-essential \
    libboost-program-options-dev \
    libboost-filesystem-dev \
    libboost-graph-dev \
    libboost-system-dev \
    libboost-regex-dev \
    libboost-test-dev \
    libeigen3-dev \
    libflann-dev \
    libfreeimage-dev \
    libmetis-dev \
    libgoogle-glog-dev \
    libgtest-dev \
    libsqlite3-dev \
    libglew-dev \
    qtbase5-dev \
    libqt5opengl5-dev \
    libcgal-dev \
    libceres-dev \
    libsuitesparse-dev \
    libgflags-dev \
    libpng-dev \
    libjpeg-dev \
    libtiff-dev \
    libxxf86vm1 \
    libxxf86vm-dev \
    libxi-dev \
    libxrandr-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# libboost-filesystem-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-filesystem-dev set to manually installed.
# libboost-program-options-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-program-options-dev set to manually installed.
# libboost-regex-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-regex-dev set to manually installed.
# libboost-system-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-system-dev set to manually installed.
# libjpeg-dev is already the newest version (8c-2ubuntu10).
# libjpeg-dev set to manually installed.
# libpng-dev is already the newest version (1.6.37-3build5).
# libxxf86vm1 is already the newest version (1:1.1.4-1build3).
# libxxf86vm1 set to manually installed.
# libboost-graph-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-graph-dev set to manually installed.
# libboost-test-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-test-dev set to manually installed.
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# libsqlite3-dev is already the newest version (3.37.2-2ubuntu0.3).
# libsqlite3-dev set to manually installed.
# libtiff-dev is already the newest version (4.3.0-6ubuntu0.10).
# libtiff-dev set to manually installed.
# The following additional packages will be installed:
#   googletest libamd2 libbtf1 libcamd2 libccolamd2 libceres2 libcholmod3
#   libcolamd2 libcxsparse3 libegl-dev libevdev2 libflann1.9 libfreeimage3
#   libgflags2.2 libgl-dev libglu1-mesa libglu1-mesa-dev libglx-dev libgmp-dev
#   libgmpxx4ldbl libgoogle-glog0v5 libgraphblas-dev libgraphblas6
#   libgudev-1.0-0 libhdf5-mpi-dev libhdf5-openmpi-103-1
#   libhdf5-openmpi-cpp-103-1 libhdf5-openmpi-dev libhdf5-openmpi-fortran-102
#   libhdf5-openmpi-hl-100 libhdf5-openmpi-hl-cpp-100
#   libhdf5-openmpi-hl-fortran-100 libinput-bin libinput10 libjxr0 libklu1
#   libldl2 libmd4c0 libmetis5 libmongoose2 libmpfr-dev libmtdev1
#   libqt5concurrent5 libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5
#   libqt5opengl5 libqt5printsupport5 libqt5sql5 libqt5sql5-sqlite libqt5svg5
#   libqt5test5 libqt5widgets5 libqt5xml5 libraw20 librbio2 libsliplu1 libspqr2
#   libsuitesparseconfig5 libumfpack5 libunwind-dev libvulkan-dev libvulkan1
#   libwacom-bin libwacom-common libwacom9 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxfixes-dev libxkbcommon-x11-0
#   mesa-vulkan-drivers qt5-gtk-platformtheme qt5-qmake qt5-qmake-bin
#   qtbase5-dev-tools qtchooser qttranslations5-l10n
# Suggested packages:
#   libmpfi-dev libntl-dev libeigen3-doc libmpfrc++-dev gmp-doc libgmp10-doc
#   libhdf5-doc libmpfr-doc qt5-image-formats-plugins qtwayland5 firebird-dev
# The following NEW packages will be installed:
#   googletest libamd2 libbtf1 libcamd2 libccolamd2 libceres-dev libceres2
#   libcgal-dev libcholmod3 libcolamd2 libcxsparse3 libegl-dev libeigen3-dev
#   libevdev2 libflann-dev libflann1.9 libfreeimage-dev libfreeimage3
#   libgflags-dev libgflags2.2 libgl-dev libglew-dev libglu1-mesa
#   libglu1-mesa-dev libglx-dev libgmp-dev libgmpxx4ldbl libgoogle-glog-dev
#   libgoogle-glog0v5 libgraphblas-dev libgraphblas6 libgtest-dev libgudev-1.0-0
#   libhdf5-mpi-dev libhdf5-openmpi-103-1 libhdf5-openmpi-cpp-103-1
#   libhdf5-openmpi-dev libhdf5-openmpi-fortran-102 libhdf5-openmpi-hl-100
#   libhdf5-openmpi-hl-cpp-100 libhdf5-openmpi-hl-fortran-100 libinput-bin
#   libinput10 libjxr0 libklu1 libldl2 libmd4c0 libmetis-dev libmetis5
#   libmongoose2 libmpfr-dev libmtdev1 libqt5concurrent5 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5opengl5 libqt5opengl5-dev
#   libqt5printsupport5 libqt5sql5 libqt5sql5-sqlite libqt5svg5 libqt5test5
#   libqt5widgets5 libqt5xml5 libraw20 librbio2 libsliplu1 libspqr2
#   libsuitesparse-dev libsuitesparseconfig5 libumfpack5 libunwind-dev
#   libvulkan-dev libvulkan1 libwacom-bin libwacom-common libwacom9
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxfixes-dev libxi-dev
#   libxkbcommon-x11-0 libxrandr-dev libxxf86vm-dev mesa-vulkan-drivers
#   ninja-build qt5-gtk-platformtheme qt5-qmake qt5-qmake-bin qtbase5-dev
#   qtbase5-dev-tools qtchooser qttranslations5-l10n
# 0 upgraded, 101 newly installed, 0 to remove and 49 not upgraded.
# Need to get 70.1 MB of archives.
# After this operation, 442 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 googletest all 1.11.0-3 [541 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libamd2 amd64 1:5.10.1+dfsg-4build1 [21.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbtf1 amd64 1:5.10.1+dfsg-4build1 [12.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcamd2 amd64 1:5.10.1+dfsg-4build1 [23.3 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libccolamd2 amd64 1:5.10.1+dfsg-4build1 [25.2 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis5 amd64 5.1.0.dfsg-7build2 [181 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcholmod3 amd64 1:5.10.1+dfsg-4build1 [346 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcxsparse3 amd64 1:5.10.1+dfsg-4build1 [70.8 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags2.2 amd64 2.2.2-2 [78.1 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog0v5 amd64 0.5.0+really0.4.0-2 [60.3 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspqr2 amd64 1:5.10.1+dfsg-4build1 [71.6 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres2 amd64 2.0.0+dfsg1-5 [834 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags-dev amd64 2.2.2-2 [93.7 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunwind-dev amd64 1.3.2-2build2.1 [1,883 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog-dev amd64 0.5.0+really0.4.0-2 [91.9 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeigen3-dev all 3.4.0-2ubuntu2 [1,056 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libklu1 amd64 1:5.10.1+dfsg-4build1 [77.6 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldl2 amd64 1:5.10.1+dfsg-4build1 [11.7 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmongoose2 amd64 1:5.10.1+dfsg-4build1 [33.5 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libumfpack5 amd64 1:5.10.1+dfsg-4build1 [250 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 librbio2 amd64 1:5.10.1+dfsg-4build1 [26.6 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsliplu1 amd64 1:5.10.1+dfsg-4build1 [37.1 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsuitesparse-dev amd64 1:5.10.1+dfsg-4build1 [1,058 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres-dev amd64 2.0.0+dfsg1-5 [1,177 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmpxx4ldbl amd64 2:6.2.1+dfsg-3ubuntu1 [9,580 B]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp-dev amd64 2:6.2.1+dfsg-3ubuntu1 [337 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmpfr-dev amd64 4.1.0-3build3 [271 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcgal-dev amd64 5.4-1 [4,784 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libflann1.9 amd64 1.9.1+dfsg-11 [742 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-103-1 amd64 1.10.7+repack-4ubuntu2 [1,344 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-fortran-102 amd64 1.10.7+repack-4ubuntu2 [90.6 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-hl-100 amd64 1.10.7+repack-4ubuntu2 [59.2 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-hl-fortran-100 amd64 1.10.7+repack-4ubuntu2 [33.5 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-cpp-103-1 amd64 1.10.7+repack-4ubuntu2 [129 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-hl-cpp-100 amd64 1.10.7+repack-4ubuntu2 [10.7 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-openmpi-dev amd64 1.10.7+repack-4ubuntu2 [2,750 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhdf5-mpi-dev amd64 1.10.7+repack-4ubuntu2 [4,610 B]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libflann-dev amd64 1.9.1+dfsg-11 [798 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas6 amd64 6.1.4+dfsg-2 [20.1 MB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas-dev amd64 6.1.4+dfsg-2 [54.4 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgtest-dev amd64 1.11.0-3 [250 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis-dev amd64 5.1.0.dfsg-7build2 [5,818 B]
# Get:75 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5concurrent5 amd64 5.15.3+dfsg-2ubuntu0.2 [36.3 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5opengl5 amd64 5.15.3+dfsg-2ubuntu0.2 [153 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5printsupport5 amd64 5.15.3+dfsg-2ubuntu0.2 [214 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5sql5 amd64 5.15.3+dfsg-2ubuntu0.2 [123 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5test5 amd64 5.15.3+dfsg-2ubuntu0.2 [152 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5xml5 amd64 5.15.3+dfsg-2ubuntu0.2 [124 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan1 amd64 1.3.204.1-2 [128 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan-dev amd64 1.3.204.1-2 [892 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-qmake-bin amd64 5.15.3+dfsg-2ubuntu0.2 [1,126 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qtchooser amd64 66-2build1 [24.7 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-qmake amd64 5.15.3+dfsg-2ubuntu0.2 [208 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qtbase5-dev-tools amd64 5.15.3+dfsg-2ubuntu0.2 [819 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qtbase5-dev amd64 5.15.3+dfsg-2ubuntu0.2 [1,135 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5opengl5-dev amd64 5.15.3+dfsg-2ubuntu0.2 [42.3 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5sql5-sqlite amd64 5.15.3+dfsg-2ubuntu0.2 [53.0 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraw20 amd64 0.20.2-2ubuntu2.22.04.1 [342 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi-dev amd64 2:1.8-1build1 [193 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr-dev amd64 2:1.5.2-1build1 [26.7 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build3 [13.9 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-vulkan-drivers amd64 23.2.1-1ubuntu3.1~22.04.2 [10.7 MB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ninja-build amd64 1.10.1-1 [111 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libfreeimage3 amd64 3.18.0+ds2-6ubuntu5.1 [294 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libfreeimage-dev amd64 3.18.0+ds2-6ubuntu5.1 [371 kB]
# Fetched 70.1 MB in 7s (10.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 101.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libqt5core5a:amd64.
# (Reading database ... 123629 files and directories currently installed.)
# Preparing to unpack .../000-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../001-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../002-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../003-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../004-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../005-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../006-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../007-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../008-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../009-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../010-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../011-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../012-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../013-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../014-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../015-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../016-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../017-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../018-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../019-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../020-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../021-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../022-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package googletest.
# Preparing to unpack .../023-googletest_1.11.0-3_all.deb ...
# Unpacking googletest (1.11.0-3) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../024-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../025-libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libbtf1:amd64.
# Preparing to unpack .../026-libbtf1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libbtf1:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../027-libcamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../028-libccolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../029-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../030-libmetis5_5.1.0.dfsg-7build2_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../031-libcholmod3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../032-libcxsparse3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../033-libgflags2.2_2.2.2-2_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-2) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../034-libgoogle-glog0v5_0.5.0+really0.4.0-2_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../035-libspqr2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libceres2.
# Preparing to unpack .../036-libceres2_2.0.0+dfsg1-5_amd64.deb ...
# Unpacking libceres2 (2.0.0+dfsg1-5) ...
# Selecting previously unselected package libgflags-dev.
# Preparing to unpack .../037-libgflags-dev_2.2.2-2_amd64.deb ...
# Unpacking libgflags-dev (2.2.2-2) ...
# Selecting previously unselected package libunwind-dev:amd64.
# Preparing to unpack .../038-libunwind-dev_1.3.2-2build2.1_amd64.deb ...
# Unpacking libunwind-dev:amd64 (1.3.2-2build2.1) ...
# Selecting previously unselected package libgoogle-glog-dev.
# Preparing to unpack .../039-libgoogle-glog-dev_0.5.0+really0.4.0-2_amd64.deb ...
# Unpacking libgoogle-glog-dev (0.5.0+really0.4.0-2) ...
# Selecting previously unselected package libeigen3-dev.
# Preparing to unpack .../040-libeigen3-dev_3.4.0-2ubuntu2_all.deb ...
# Unpacking libeigen3-dev (3.4.0-2ubuntu2) ...
# Selecting previously unselected package libklu1:amd64.
# Preparing to unpack .../041-libklu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libklu1:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libldl2:amd64.
# Preparing to unpack .../042-libldl2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libldl2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libmongoose2:amd64.
# Preparing to unpack .../043-libmongoose2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libmongoose2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libumfpack5:amd64.
# Preparing to unpack .../044-libumfpack5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libumfpack5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package librbio2:amd64.
# Preparing to unpack .../045-librbio2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking librbio2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libsliplu1:amd64.
# Preparing to unpack .../046-libsliplu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsliplu1:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libsuitesparse-dev:amd64.
# Preparing to unpack .../047-libsuitesparse-dev_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparse-dev:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libceres-dev.
# Preparing to unpack .../048-libceres-dev_2.0.0+dfsg1-5_amd64.deb ...
# Unpacking libceres-dev (2.0.0+dfsg1-5) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../049-libgmpxx4ldbl_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../050-libgmp-dev_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Selecting previously unselected package libmpfr-dev:amd64.
# Preparing to unpack .../051-libmpfr-dev_4.1.0-3build3_amd64.deb ...
# Unpacking libmpfr-dev:amd64 (4.1.0-3build3) ...
# Selecting previously unselected package libcgal-dev:amd64.
# Preparing to unpack .../052-libcgal-dev_5.4-1_amd64.deb ...
# Unpacking libcgal-dev:amd64 (5.4-1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../053-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../054-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../055-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libflann1.9:amd64.
# Preparing to unpack .../056-libflann1.9_1.9.1+dfsg-11_amd64.deb ...
# Unpacking libflann1.9:amd64 (1.9.1+dfsg-11) ...
# Selecting previously unselected package libhdf5-openmpi-103-1:amd64.
# Preparing to unpack .../057-libhdf5-openmpi-103-1_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-openmpi-103-1:amd64 (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libhdf5-openmpi-fortran-102:amd64.
# Preparing to unpack .../058-libhdf5-openmpi-fortran-102_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-openmpi-fortran-102:amd64 (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libhdf5-openmpi-hl-100:amd64.
# Preparing to unpack .../059-libhdf5-openmpi-hl-100_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-openmpi-hl-100:amd64 (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libhdf5-openmpi-hl-fortran-100:amd64.
# Preparing to unpack .../060-libhdf5-openmpi-hl-fortran-100_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-openmpi-hl-fortran-100:amd64 (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libhdf5-openmpi-cpp-103-1:amd64.
# Preparing to unpack .../061-libhdf5-openmpi-cpp-103-1_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-openmpi-cpp-103-1:amd64 (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libhdf5-openmpi-hl-cpp-100:amd64.
# Preparing to unpack .../062-libhdf5-openmpi-hl-cpp-100_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-openmpi-hl-cpp-100:amd64 (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libhdf5-openmpi-dev.
# Preparing to unpack .../063-libhdf5-openmpi-dev_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-openmpi-dev (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libhdf5-mpi-dev.
# Preparing to unpack .../064-libhdf5-mpi-dev_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking libhdf5-mpi-dev (1.10.7+repack-4ubuntu2) ...
# Selecting previously unselected package libflann-dev:amd64.
# Preparing to unpack .../065-libflann-dev_1.9.1+dfsg-11_amd64.deb ...
# Unpacking libflann-dev:amd64 (1.9.1+dfsg-11) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../066-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../067-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../068-libglew-dev_2.2.0-4_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.2.0-4) ...
# Selecting previously unselected package libgraphblas6:amd64.
# Preparing to unpack .../069-libgraphblas6_6.1.4+dfsg-2_amd64.deb ...
# Unpacking libgraphblas6:amd64 (6.1.4+dfsg-2) ...
# Selecting previously unselected package libgraphblas-dev:amd64.
# Preparing to unpack .../070-libgraphblas-dev_6.1.4+dfsg-2_amd64.deb ...
# Unpacking libgraphblas-dev:amd64 (6.1.4+dfsg-2) ...
# Selecting previously unselected package libgtest-dev:amd64.
# Preparing to unpack .../071-libgtest-dev_1.11.0-3_amd64.deb ...
# Unpacking libgtest-dev:amd64 (1.11.0-3) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../072-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libmetis-dev.
# Preparing to unpack .../073-libmetis-dev_5.1.0.dfsg-7build2_amd64.deb ...
# Unpacking libmetis-dev (5.1.0.dfsg-7build2) ...
# Selecting previously unselected package libqt5concurrent5:amd64.
# Preparing to unpack .../074-libqt5concurrent5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5concurrent5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5opengl5:amd64.
# Preparing to unpack .../075-libqt5opengl5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5opengl5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5printsupport5:amd64.
# Preparing to unpack .../076-libqt5printsupport5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5printsupport5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5sql5:amd64.
# Preparing to unpack .../077-libqt5sql5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5sql5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5test5:amd64.
# Preparing to unpack .../078-libqt5test5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5test5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5xml5:amd64.
# Preparing to unpack .../079-libqt5xml5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5xml5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../080-libvulkan1_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libvulkan-dev:amd64.
# Preparing to unpack .../081-libvulkan-dev_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan-dev:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package qt5-qmake-bin.
# Preparing to unpack .../082-qt5-qmake-bin_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-qmake-bin (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qtchooser.
# Preparing to unpack .../083-qtchooser_66-2build1_amd64.deb ...
# Unpacking qtchooser (66-2build1) ...
# Selecting previously unselected package qt5-qmake:amd64.
# Preparing to unpack .../084-qt5-qmake_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-qmake:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qtbase5-dev-tools.
# Preparing to unpack .../085-qtbase5-dev-tools_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qtbase5-dev-tools (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qtbase5-dev:amd64.
# Preparing to unpack .../086-qtbase5-dev_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qtbase5-dev:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5opengl5-dev:amd64.
# Preparing to unpack .../087-libqt5opengl5-dev_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5opengl5-dev:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5sql5-sqlite:amd64.
# Preparing to unpack .../088-libqt5sql5-sqlite_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5sql5-sqlite:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libraw20:amd64.
# Preparing to unpack .../089-libraw20_0.20.2-2ubuntu2.22.04.1_amd64.deb ...
# Unpacking libraw20:amd64 (0.20.2-2ubuntu2.22.04.1) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../090-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../091-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../092-libxi-dev_2%3a1.8-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8-1build1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../093-libxrandr-dev_2%3a1.5.2-1build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../094-libxxf86vm-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../095-mesa-vulkan-drivers_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package ninja-build.
# Preparing to unpack .../096-ninja-build_1.10.1-1_amd64.deb ...
# Unpacking ninja-build (1.10.1-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../097-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../098-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Selecting previously unselected package libfreeimage3:amd64.
# Preparing to unpack .../099-libfreeimage3_3.18.0+ds2-6ubuntu5.1_amd64.deb ...
# Unpacking libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Selecting previously unselected package libfreeimage-dev.
# Preparing to unpack .../100-libfreeimage-dev_3.18.0+ds2-6ubuntu5.1_amd64.deb ...
# Unpacking libfreeimage-dev (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libunwind-dev:amd64 (1.3.2-2build2.1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Setting up libgraphblas6:amd64 (6.1.4+dfsg-2) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libldl2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up googletest (1.11.0-3) ...
# Setting up libbtf1:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up ninja-build (1.10.1-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up libgraphblas-dev:amd64 (6.1.4+dfsg-2) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up qt5-qmake-bin (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libeigen3-dev (3.4.0-2ubuntu2) ...
# Setting up libflann1.9:amd64 (1.9.1+dfsg-11) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libraw20:amd64 (0.20.2-2ubuntu2.22.04.1) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libvulkan1:amd64 (1.3.204.1-2) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libxi-dev:amd64 (2:1.8-1build1) ...
# Setting up libqt5test5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libqt5concurrent5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up qtchooser (66-2build1) ...
# Setting up librbio2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libhdf5-openmpi-103-1:amd64 (1.10.7+repack-4ubuntu2) ...
# Setting up libgflags2.2 (2.2.2-2) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libvulkan-dev:amd64 (1.3.204.1-2) ...
# Setting up libgmp-dev:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgtest-dev:amd64 (1.11.0-3) ...
# Setting up qt5-qmake:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libmetis-dev (5.1.0.dfsg-7build2) ...
# Setting up libmpfr-dev:amd64 (4.1.0-3build3) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up libcgal-dev:amd64 (5.4-1) ...
# Setting up libsliplu1:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5sql5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up qtbase5-dev-tools (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libmongoose2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5xml5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libhdf5-openmpi-fortran-102:amd64 (1.10.7+repack-4ubuntu2) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libgflags-dev (2.2.2-2) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libklu1:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libhdf5-openmpi-hl-100:amd64 (1.10.7+repack-4ubuntu2) ...
# Setting up libhdf5-openmpi-cpp-103-1:amd64 (1.10.7+repack-4ubuntu2) ...
# Setting up libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Setting up libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libhdf5-openmpi-hl-cpp-100:amd64 (1.10.7+repack-4ubuntu2) ...
# Setting up libfreeimage-dev (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libhdf5-openmpi-hl-fortran-100:amd64 (1.10.7+repack-4ubuntu2) ...
# Setting up libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5sql5-sqlite:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5printsupport5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libglew-dev:amd64 (2.2.0-4) ...
# Setting up libumfpack5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libceres2 (2.0.0+dfsg1-5) ...
# Setting up qtbase5-dev:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5opengl5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libgoogle-glog-dev (0.5.0+really0.4.0-2) ...
# Setting up libhdf5-openmpi-dev (1.10.7+repack-4ubuntu2) ...
# update-alternatives: using /usr/bin/h5pcc.openmpi to provide /usr/bin/h5pcc (h5pcc) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/pkgconfig/hdf5-openmpi.pc to provide /usr/lib/x86_64-linux-gnu/pkgconfig/hdf5.pc (hdf5.pc) in auto mode
# update-alternatives: updating alternative /usr/bin/mpicc.openmpi because link group mpi has changed slave links
# update-alternatives: using /usr/lib/x86_64-linux-gnu/pkgconfig/hdf5-mpi.pc to provide /usr/lib/x86_64-linux-gnu/pkgconfig/hdf5.pc (hdf5.pc) in auto mode
# Setting up libqt5opengl5-dev:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libsuitesparse-dev:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Setting up libhdf5-mpi-dev (1.10.7+repack-4ubuntu2) ...
# Setting up libceres-dev (2.0.0+dfsg1-5) ...
# Setting up libflann-dev:amd64 (1.9.1+dfsg-11) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# # COLMAP Build (~48 min)

# %%
# %cd /content/drive/MyDrive/final_project_gsplat/
# !git clone https://github.com/colmap/colmap.git
# Out:
# /content/drive/MyDrive/final_project_gsplat
# fatal: destination path 'colmap' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/final_project_gsplat/colmap
# !mkdir build

# %cd /content/drive/MyDrive/final_project_gsplat/colmap/build
# !cmake ..
# !make -j$(nproc)
# !sudo make install
# Out:
# /content/drive/MyDrive/final_project_gsplat/colmap
# mkdir: cannot create directory ‘build’: File exists
# /content/drive/MyDrive/final_project_gsplat/colmap/build
# -- Enabling LSD support
# -- Found FreeImage
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libfreeimage.so
# -- Found FLANN
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libflann.so
# -- Found LZ4
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/liblz4.so
# -- Found Metis
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libmetis.so
# -- Found Glog
# --   Target : glog::glog
# -- Found Glew
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libGLEW.so
# -- Found required Ceres dependency: Eigen version 3.4.0 in /usr/include/eigen3
# -- Found required Ceres dependency: glog
# -- Found required Ceres dependency: gflags
# -- Found Ceres version: 2.0.0 installed in: /usr with components: [EigenSparse, SparseLinearAlgebraLibrary, LAPACK, SuiteSparse, CXSparse, SchurSpecializations, Multithreading]
# -- Enabling OpenMP support
# -- Using header-only CGAL
# -- Targetting Unix Makefiles
# -- Using /usr/bin/c++ compiler.
# -- Boost include dirs: /usr/include
# -- Boost libraries:
# -- Using gcc version 4 or later. Adding -frounding-math
# -- Found CGAL
# --   Includes : /usr/include
# --   Libraries : CGAL
# -- Enabling CUDA support (version: 12.2.140, archs: native)
# -- Found Qt
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Core
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5OpenGL
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Widgets
# -- Enabling GUI support
# -- Enabling OpenGL support
# -- Enabling GPU support (OpenGL: ON, CUDA: ON)
# -- Build type not specified, using Release
# -- Enabling SIMD support
# -- Disabling interprocedural optimization
# -- Disabling ccache support
# -- Disabling profiling support
# -- Configuring PoseLib...
# -- BUILD_SHARED_LIBS: OFF
# -- CMAKE_BUILD_TYPE: Release
# -- CMAKE_GENERATOR: Single-config
# -- CMAKE_GENERATOR: Unix Makefiles
# -- CMAKE_REGISTRY_FOLDER: OFF
# -- Configuring PoseLib... done
# -- Configuring done (90.4s)
# -- Generating done (210.2s)
# -- Build files have been written to: /content/drive/MyDrive/final_project_gsplat/colmap/build
# [ -4%] Built target colmap_lsd
# [ -2%] Built target colmap_poisson_recon
# [  4%] Built target colmap_util
# [  4%] Built target colmap_feature_types
# [  4%] Built target colmap_util_cuda
# [  8%] Built target colmap_sift_gpu
# [ 10%] Built target colmap_math
# [ 12%] Built target colmap_geometry
# [ 14%] Built target colmap_optim
# [ 29%] Built target colmap_vlfeat
# [ 31%] Built target colmap_sensor
# [ 47%] Built target PoseLib
# [ 54%] Built target colmap_scene
# [ 56%] Built target colmap_image
# [ 60%] Built target colmap_mvs
# [ 62%] Built target colmap_mvs_cuda
# [ 70%] Built target colmap_estimators
# [ 72%] Built target colmap_retrieval
# [ 75%] Built target colmap_sfm
# [ 79%] Built target colmap_feature
# [ 81%] Built target colmap_controllers
# [ 81%] Built target colmap_exe
# [ 91%] Built target colmap_ui
# [ 95%] Built target colmap_main
# [ 12%] Built target PoseLib
# [ 18%] Built target colmap_util
# [ 18%] Built target colmap_feature_types
# [ 20%] Built target colmap_math
# [ 22%] Built target colmap_geometry
# [ 37%] Built target colmap_vlfeat
# [ 39%] Built target colmap_sensor
# [ 45%] Built target colmap_scene
# [ 45%] Built target colmap_lsd
# [ 47%] Built target colmap_image
# [ 50%] Built target colmap_optim
# [ 50%] Built target colmap_util_cuda
# [ 58%] Built target colmap_estimators
# [ 60%] Built target colmap_retrieval
# [ 64%] Built target colmap_sift_gpu
# [ 68%] Built target colmap_feature
# [ 70%] Built target colmap_poisson_recon
# [ 75%] Built target colmap_mvs
# [ 77%] Built target colmap_sfm
# [ 79%] Built target colmap_controllers
# [ 79%] Built target colmap_exe
# [ 81%] Built target colmap_mvs_cuda
# [ 91%] Built target colmap_ui
# [ 95%] Built target colmap_main
# Install the project...
# -- Install configuration: "Release"
# -- Installing: /usr/local/share/applications/COLMAP.desktop
# -- Installing: /usr/local/lib/libcolmap_controllers.a
# -- Installing: /usr/local/lib/libcolmap_estimators.a
# -- Installing: /usr/local/lib/libcolmap_exe.a
# -- Installing: /usr/local/lib/libcolmap_feature_types.a
# -- Installing: /usr/local/lib/libcolmap_feature.a
# -- Installing: /usr/local/lib/libcolmap_geometry.a
# -- Installing: /usr/local/lib/libcolmap_image.a
# -- Installing: /usr/local/lib/libcolmap_math.a
# -- Installing: /usr/local/lib/libcolmap_mvs.a
# -- Installing: /usr/local/lib/libcolmap_optim.a
# -- Installing: /usr/local/lib/libcolmap_retrieval.a
# -- Installing: /usr/local/lib/libcolmap_scene.a
# -- Installing: /usr/local/lib/libcolmap_sensor.a
# -- Installing: /usr/local/lib/libcolmap_sfm.a
# -- Installing: /usr/local/lib/libcolmap_util.a
# -- Installing: /usr/local/lib/libcolmap_poisson_recon.a
# -- Installing: /usr/local/lib/libcolmap_vlfeat.a
# -- Installing: /usr/local/lib/libPoseLib.a
# -- Installing: /usr/local/lib/libcolmap_lsd.a
# -- Installing: /usr/local/lib/libcolmap_ui.a
# -- Installing: /usr/local/lib/libcolmap_util_cuda.a
# -- Installing: /usr/local/lib/libcolmap_mvs_cuda.a
# -- Installing: /usr/local/lib/libcolmap_sift_gpu.a
# -- Installing: /usr/local/share/colmap/colmap-config.cmake
# -- Installing: /usr/local/share/colmap/colmap-config-version.cmake
# -- Installing: /usr/local/share/colmap/colmap-targets.cmake
# -- Installing: /usr/local/share/colmap/colmap-targets-release.cmake
# -- Installing: /usr/local/include/colmap
# -- Installing: /usr/local/include/colmap/controllers
# -- Installing: /usr/local/include/colmap/controllers/automatic_reconstruction.h
# -- Installing: /usr/local/include/colmap/controllers/bundle_adjustment.h
# -- Installing: /usr/local/include/colmap/controllers/feature_extraction.h
# -- Installing: /usr/local/include/colmap/controllers/feature_matching.h
# -- Installing: /usr/local/include/colmap/controllers/feature_matching_utils.h
# -- Installing: /usr/local/include/colmap/controllers/hierarchical_mapper.h
# -- Installing: /usr/local/include/colmap/controllers/image_reader.h
# -- Installing: /usr/local/include/colmap/controllers/incremental_mapper.h
# -- Installing: /usr/local/include/colmap/controllers/option_manager.h
# -- Installing: /usr/local/include/colmap/estimators
# -- Installing: /usr/local/include/colmap/estimators/absolute_pose.h
# -- Installing: /usr/local/include/colmap/estimators/affine_transform.h
# -- Installing: /usr/local/include/colmap/estimators/alignment.h
# -- Installing: /usr/local/include/colmap/estimators/bundle_adjustment.h
# -- Installing: /usr/local/include/colmap/estimators/coordinate_frame.h
# -- Installing: /usr/local/include/colmap/estimators/cost_functions.h
# -- Installing: /usr/local/include/colmap/estimators/covariance.h
# -- Installing: /usr/local/include/colmap/estimators/essential_matrix.h
# -- Installing: /usr/local/include/colmap/estimators/essential_matrix_coeffs.h
# -- Installing: /usr/local/include/colmap/estimators/essential_matrix_poly.h
# -- Installing: /usr/local/include/colmap/estimators/euclidean_transform.h
# -- Installing: /usr/local/include/colmap/estimators/fundamental_matrix.h
# -- Installing: /usr/local/include/colmap/estimators/generalized_absolute_pose.h
# -- Installing: /usr/local/include/colmap/estimators/generalized_absolute_pose_coeffs.h
# -- Installing: /usr/local/include/colmap/estimators/generalized_pose.h
# -- Installing: /usr/local/include/colmap/estimators/generalized_relative_pose.h
# -- Installing: /usr/local/include/colmap/estimators/homography_matrix.h
# -- Installing: /usr/local/include/colmap/estimators/manifold.h
# -- Installing: /usr/local/include/colmap/estimators/pose.h
# -- Installing: /usr/local/include/colmap/estimators/similarity_transform.h
# -- Installing: /usr/local/include/colmap/estimators/translation_transform.h
# -- Installing: /usr/local/include/colmap/estimators/triangulation.h
# -- Installing: /usr/local/include/colmap/estimators/two_view_geometry.h
# -- Installing: /usr/local/include/colmap/estimators/utils.h
# -- Installing: /usr/local/include/colmap/exe
# -- Installing: /usr/local/include/colmap/exe/database.h
# -- Installing: /usr/local/include/colmap/exe/feature.h
# -- Installing: /usr/local/include/colmap/exe/gui.h
# -- Installing: /usr/local/include/colmap/exe/image.h
# -- Installing: /usr/local/include/colmap/exe/model.h
# -- Installing: /usr/local/include/colmap/exe/mvs.h
# -- Installing: /usr/local/include/colmap/exe/sfm.h
# -- Installing: /usr/local/include/colmap/exe/vocab_tree.h
# -- Installing: /usr/local/include/colmap/feature
# -- Installing: /usr/local/include/colmap/feature/extractor.h
# -- Installing: /usr/local/include/colmap/feature/index.h
# -- Installing: /usr/local/include/colmap/feature/matcher.h
# -- Installing: /usr/local/include/colmap/feature/pairing.h
# -- Installing: /usr/local/include/colmap/feature/sift.h
# -- Installing: /usr/local/include/colmap/feature/types.h
# -- Installing: /usr/local/include/colmap/feature/utils.h
# -- Installing: /usr/local/include/colmap/geometry
# -- Installing: /usr/local/include/colmap/geometry/essential_matrix.h
# -- Installing: /usr/local/include/colmap/geometry/gps.h
# -- Installing: /usr/local/include/colmap/geometry/homography_matrix.h
# -- Installing: /usr/local/include/colmap/geometry/pose.h
# -- Installing: /usr/local/include/colmap/geometry/rigid3.h
# -- Installing: /usr/local/include/colmap/geometry/sim3.h
# -- Installing: /usr/local/include/colmap/geometry/triangulation.h
# -- Installing: /usr/local/include/colmap/image
# -- Installing: /usr/local/include/colmap/image/line.h
# -- Installing: /usr/local/include/colmap/image/undistortion.h
# -- Installing: /usr/local/include/colmap/image/warp.h
# -- Installing: /usr/local/include/colmap/math
# -- Installing: /usr/local/include/colmap/math/graph_cut.h
# -- Installing: /usr/local/include/colmap/math/math.h
# -- Installing: /usr/local/include/colmap/math/matrix.h
# -- Installing: /usr/local/include/colmap/math/polynomial.h
# -- Installing: /usr/local/include/colmap/math/random.h
# -- Installing: /usr/local/include/colmap/mvs
# -- Installing: /usr/local/include/colmap/mvs/consistency_graph.h
# -- Installing: /usr/local/include/colmap/mvs/cuda_flip.h
# -- Installing: /usr/local/include/colmap/mvs/cuda_rotate.h
# -- Installing: /usr/local/include/colmap/mvs/cuda_texture.h
# -- Installing: /usr/local/include/colmap/mvs/cuda_transpose.h
# -- Installing: /usr/local/include/colmap/mvs/depth_map.h
# -- Installing: /usr/local/include/colmap/mvs/fusion.h
# -- Installing: /usr/local/include/colmap/mvs/gpu_mat.h
# -- Installing: /usr/local/include/colmap/mvs/gpu_mat_prng.h
# -- Installing: /usr/local/include/colmap/mvs/gpu_mat_ref_image.h
# -- Installing: /usr/local/include/colmap/mvs/image.h
# -- Installing: /usr/local/include/colmap/mvs/mat.h
# -- Installing: /usr/local/include/colmap/mvs/meshing.h
# -- Installing: /usr/local/include/colmap/mvs/model.h
# -- Installing: /usr/local/include/colmap/mvs/normal_map.h
# -- Installing: /usr/local/include/colmap/mvs/patch_match.h
# -- Installing: /usr/local/include/colmap/mvs/patch_match_cuda.h
# -- Installing: /usr/local/include/colmap/mvs/workspace.h
# -- Installing: /usr/local/include/colmap/optim
# -- Installing: /usr/local/include/colmap/optim/combination_sampler.h
# -- Installing: /usr/local/include/colmap/optim/least_absolute_deviations.h
# -- Installing: /usr/local/include/colmap/optim/loransac.h
# -- Installing: /usr/local/include/colmap/optim/progressive_sampler.h
# -- Installing: /usr/local/include/colmap/optim/random_sampler.h
# -- Installing: /usr/local/include/colmap/optim/ransac.h
# -- Installing: /usr/local/include/colmap/optim/sampler.h
# -- Installing: /usr/local/include/colmap/optim/sprt.h
# -- Installing: /usr/local/include/colmap/optim/support_measurement.h
# -- Installing: /usr/local/include/colmap/retrieval
# -- Installing: /usr/local/include/colmap/retrieval/geometry.h
# -- Installing: /usr/local/include/colmap/retrieval/inverted_file.h
# -- Installing: /usr/local/include/colmap/retrieval/inverted_file_entry.h
# -- Installing: /usr/local/include/colmap/retrieval/inverted_index.h
# -- Installing: /usr/local/include/colmap/retrieval/utils.h
# -- Installing: /usr/local/include/colmap/retrieval/visual_index.h
# -- Installing: /usr/local/include/colmap/retrieval/vote_and_verify.h
# -- Installing: /usr/local/include/colmap/scene
# -- Installing: /usr/local/include/colmap/scene/camera.h
# -- Installing: /usr/local/include/colmap/scene/camera_rig.h
# -- Installing: /usr/local/include/colmap/scene/correspondence_graph.h
# -- Installing: /usr/local/include/colmap/scene/database.h
# -- Installing: /usr/local/include/colmap/scene/database_cache.h
# -- Installing: /usr/local/include/colmap/scene/image.h
# -- Installing: /usr/local/include/colmap/scene/point2d.h
# -- Installing: /usr/local/include/colmap/scene/point3d.h
# -- Installing: /usr/local/include/colmap/scene/projection.h
# -- Installing: /usr/local/include/colmap/scene/reconstruction.h
# -- Installing: /usr/local/include/colmap/scene/reconstruction_io.h
# -- Installing: /usr/local/include/colmap/scene/reconstruction_manager.h
# -- Installing: /usr/local/include/colmap/scene/scene_clustering.h
# -- Installing: /usr/local/include/colmap/scene/synthetic.h
# -- Installing: /usr/local/include/colmap/scene/track.h
# -- Installing: /usr/local/include/colmap/scene/two_view_geometry.h
# -- Installing: /usr/local/include/colmap/scene/visibility_pyramid.h
# -- Installing: /usr/local/include/colmap/sensor
# -- Installing: /usr/local/include/colmap/sensor/bitmap.h
# -- Installing: /usr/local/include/colmap/sensor/database.h
# -- Installing: /usr/local/include/colmap/sensor/models.h
# -- Installing: /usr/local/include/colmap/sensor/specs.h
# -- Installing: /usr/local/include/colmap/sfm
# -- Installing: /usr/local/include/colmap/sfm/incremental_mapper.h
# -- Installing: /usr/local/include/colmap/sfm/incremental_triangulator.h
# -- Installing: /usr/local/include/colmap/sfm/observation_manager.h
# -- Installing: /usr/local/include/colmap/tools
# -- Installing: /usr/local/include/colmap/ui
# -- Installing: /usr/local/include/colmap/ui/automatic_reconstruction_widget.h
# -- Installing: /usr/local/include/colmap/ui/bundle_adjustment_widget.h
# -- Installing: /usr/local/include/colmap/ui/colormaps.h
# -- Installing: /usr/local/include/colmap/ui/database_management_widget.h
# -- Installing: /usr/local/include/colmap/ui/dense_reconstruction_widget.h
# -- Installing: /usr/local/include/colmap/ui/feature_extraction_widget.h
# -- Installing: /usr/local/include/colmap/ui/feature_matching_widget.h
# -- Installing: /usr/local/include/colmap/ui/image_viewer_widget.h
# -- Installing: /usr/local/include/colmap/ui/license_widget.h
# -- Installing: /usr/local/include/colmap/ui/line_painter.h
# -- Installing: /usr/local/include/colmap/ui/log_widget.h
# -- Installing: /usr/local/include/colmap/ui/main_window.h
# -- Installing: /usr/local/include/colmap/ui/match_matrix_widget.h
# -- Installing: /usr/local/include/colmap/ui/media
# -- Installing: /usr/local/include/colmap/ui/model_viewer_widget.h
# -- Installing: /usr/local/include/colmap/ui/movie_grabber_widget.h
# -- Installing: /usr/local/include/colmap/ui/options_widget.h
# -- Installing: /usr/local/include/colmap/ui/point_painter.h
# -- Installing: /usr/local/include/colmap/ui/point_viewer_widget.h
# -- Installing: /usr/local/include/colmap/ui/project_widget.h
# -- Installing: /usr/local/include/colmap/ui/qt_utils.h
# -- Installing: /usr/local/include/colmap/ui/reconstruction_manager_widget.h
# -- Installing: /usr/local/include/colmap/ui/reconstruction_options_widget.h
# -- Installing: /usr/local/include/colmap/ui/reconstruction_stats_widget.h
# -- Installing: /usr/local/include/colmap/ui/render_options.h
# -- Installing: /usr/local/include/colmap/ui/render_options_widget.h
# -- Installing: /usr/local/include/colmap/ui/shaders
# -- Installing: /usr/local/include/colmap/ui/thread_control_widget.h
# -- Installing: /usr/local/include/colmap/ui/triangle_painter.h
# -- Installing: /usr/local/include/colmap/ui/undistortion_widget.h
# -- Installing: /usr/local/include/colmap/util
# -- Installing: /usr/local/include/colmap/util/base_controller.h
# -- Installing: /usr/local/include/colmap/util/cache.h
# -- Installing: /usr/local/include/colmap/util/controller_thread.h
# -- Installing: /usr/local/include/colmap/util/cuda.h
# -- Installing: /usr/local/include/colmap/util/cudacc.h
# -- Installing: /usr/local/include/colmap/util/eigen_alignment.h
# -- Installing: /usr/local/include/colmap/util/endian.h
# -- Installing: /usr/local/include/colmap/util/file.h
# -- Installing: /usr/local/include/colmap/util/logging.h
# -- Installing: /usr/local/include/colmap/util/misc.h
# -- Installing: /usr/local/include/colmap/util/opengl_utils.h
# -- Installing: /usr/local/include/colmap/util/ply.h
# -- Installing: /usr/local/include/colmap/util/sqlite3_utils.h
# -- Installing: /usr/local/include/colmap/util/string.h
# -- Installing: /usr/local/include/colmap/util/testing.h
# -- Installing: /usr/local/include/colmap/util/threading.h
# -- Installing: /usr/local/include/colmap/util/timer.h
# -- Installing: /usr/local/include/colmap/util/types.h
# -- Installing: /usr/local/include/colmap/util/version.h
# -- Installing: /usr/local/include/colmap/thirdparty
# -- Installing: /usr/local/include/colmap/thirdparty/LSD
# -- Installing: /usr/local/include/colmap/thirdparty/LSD/lsd.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Allocator.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Array.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Array.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/BSplineData.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/BSplineData.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/BinaryNode.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/CmdLineParser.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/CmdLineParser.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Factor.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/FunctionData.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/FunctionData.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Geometry.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Geometry.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Hash.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MAT.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MAT.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MarchingCubes.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MemoryUsage.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MultiGridOctreeData.Evaluation.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MultiGridOctreeData.IsoSurface.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MultiGridOctreeData.SortedTreeNodes.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MultiGridOctreeData.System.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MultiGridOctreeData.WeightedSamples.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MultiGridOctreeData.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MultiGridOctreeData.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/MyTime.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Octree.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Octree.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/PPolynomial.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/PPolynomial.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Ply.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/PointStream.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/PointStream.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/PoissonRecon.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Polynomial.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/Polynomial.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/SparseMatrix.h
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/SparseMatrix.inl
# -- Installing: /usr/local/include/colmap/thirdparty/PoissonRecon/SurfaceTrimmer.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/CLTexImage.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/CuTexImage.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/FrameBufferObject.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/GLTexImage.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/GlobalUtil.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/LiteWindow.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/ProgramCG.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/ProgramCL.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/ProgramCU.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/ProgramGLSL.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/ProgramGPU.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/PyramidCL.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/PyramidCU.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/PyramidGL.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/ShaderMan.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/SiftGPU.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/SiftMatch.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/SiftMatchCU.h
# -- Installing: /usr/local/include/colmap/thirdparty/SiftGPU/SiftPyramid.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/aib.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/array.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/covdet.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/dsift.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/fisher.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/float.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/generic.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/getopt_long.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/gmm.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/heap-def.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/hikmeans.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/hog.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/homkermap.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/host.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/ikmeans.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/imopv.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/imopv_sse2.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/kdtree.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/kmeans.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/lbp.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/liop.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/mathop.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/mathop_avx.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/mathop_sse2.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/mser.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/pgm.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/qsort-def.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/quickshift.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/random.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/rodrigues.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/scalespace.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/shuffle-def.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/sift.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/slic.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/stringop.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/svm.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/svmdataset.h
# -- Installing: /usr/local/include/colmap/thirdparty/VLFeat/vlad.h
# -- Installing: /usr/local/share/colmap/cmake
# -- Installing: /usr/local/share/colmap/cmake/FindDependencies.cmake
# -- Installing: /usr/local/share/colmap/cmake/FindFLANN.cmake
# -- Installing: /usr/local/share/colmap/cmake/FindFreeImage.cmake
# -- Installing: /usr/local/share/colmap/cmake/FindGlew.cmake
# -- Installing: /usr/local/share/colmap/cmake/FindGlog.cmake
# -- Installing: /usr/local/share/colmap/cmake/FindLZ4.cmake
# -- Installing: /usr/local/share/colmap/cmake/FindMetis.cmake
# -- Installing: /usr/local/bin/colmap
# -- Set non-toolchain portion of runtime path of "/usr/local/bin/colmap" to ""

# %% [markdown]
# # Construct Structure-from-Motion (SfM) of the scene with COLMAP library

# %%
# %cd /content/drive/MyDrive/final_project_gsplat/gaussian-splatting
# !python convert.py -s /content/drive/MyDrive/final_project_gsplat/gaussian-splatting/data/sv302
# Out:
# /content/drive/MyDrive/final_project_gsplat/gaussian-splatting
# I1120 18:22:24.969369  6744 misc.cc:44]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I1120 18:22:24.970501  6753 sift.cc:721] Creating SIFT GPU feature extractor
# I1120 18:22:28.126628  6754 feature_extraction.cc:258] Processed file [1/254]
# I1120 18:22:28.126668  6754 feature_extraction.cc:261]   Name:            P1370830.JPG
# I1120 18:22:28.126673  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:28.126677  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:28.126681  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:28.126690  6754 feature_extraction.cc:280]   Features:        4404
# I1120 18:22:41.540091  6754 feature_extraction.cc:258] Processed file [2/254]
# I1120 18:22:41.540122  6754 feature_extraction.cc:261]   Name:            P1370833.JPG
# I1120 18:22:41.540125  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:41.540128  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:41.540132  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:41.540144  6754 feature_extraction.cc:280]   Features:        10224
# I1120 18:22:41.593561  6754 feature_extraction.cc:258] Processed file [3/254]
# I1120 18:22:41.593597  6754 feature_extraction.cc:261]   Name:            P1370834.JPG
# I1120 18:22:41.593602  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:41.593605  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:41.593609  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:41.593622  6754 feature_extraction.cc:280]   Features:        11147
# I1120 18:22:43.480508  6754 feature_extraction.cc:258] Processed file [4/254]
# I1120 18:22:43.480538  6754 feature_extraction.cc:261]   Name:            P1370835.JPG
# I1120 18:22:43.480542  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:43.480546  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:43.480567  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:43.480582  6754 feature_extraction.cc:280]   Features:        10169
# I1120 18:22:43.518536  6754 feature_extraction.cc:258] Processed file [5/254]
# I1120 18:22:43.518576  6754 feature_extraction.cc:261]   Name:            P1370836.JPG
# I1120 18:22:43.518586  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:43.518595  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:43.518604  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:43.518620  6754 feature_extraction.cc:280]   Features:        7655
# I1120 18:22:44.917558  6754 feature_extraction.cc:258] Processed file [6/254]
# I1120 18:22:44.917608  6754 feature_extraction.cc:261]   Name:            P1370837.JPG
# I1120 18:22:44.917613  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:44.917615  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:44.917619  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:44.917629  6754 feature_extraction.cc:280]   Features:        10542
# I1120 18:22:45.048311  6754 feature_extraction.cc:258] Processed file [7/254]
# I1120 18:22:45.048352  6754 feature_extraction.cc:261]   Name:            P1370838.JPG
# I1120 18:22:45.048358  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:45.048363  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:45.048373  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:45.048398  6754 feature_extraction.cc:280]   Features:        11791
# I1120 18:22:46.878329  6754 feature_extraction.cc:258] Processed file [8/254]
# I1120 18:22:46.878358  6754 feature_extraction.cc:261]   Name:            P1370839.JPG
# I1120 18:22:46.878361  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:46.878365  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:46.878386  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:46.878394  6754 feature_extraction.cc:280]   Features:        10209
# I1120 18:22:46.929215  6754 feature_extraction.cc:258] Processed file [9/254]
# I1120 18:22:46.929248  6754 feature_extraction.cc:261]   Name:            P1370840.JPG
# I1120 18:22:46.929255  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:46.929258  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:46.929263  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:46.929276  6754 feature_extraction.cc:280]   Features:        9253
# I1120 18:22:47.571520  6754 feature_extraction.cc:258] Processed file [10/254]
# I1120 18:22:47.571566  6754 feature_extraction.cc:261]   Name:            P1370841.JPG
# I1120 18:22:47.571573  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:47.571578  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:47.571584  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:47.571600  6754 feature_extraction.cc:280]   Features:        10992
# I1120 18:22:47.615869  6754 feature_extraction.cc:258] Processed file [11/254]
# I1120 18:22:47.615900  6754 feature_extraction.cc:261]   Name:            P1370842.JPG
# I1120 18:22:47.615906  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:47.615911  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:47.615917  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:47.615932  6754 feature_extraction.cc:280]   Features:        10647
# I1120 18:22:49.467572  6754 feature_extraction.cc:258] Processed file [12/254]
# I1120 18:22:49.467625  6754 feature_extraction.cc:261]   Name:            P1370843.JPG
# I1120 18:22:49.467630  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:49.467638  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:49.467656  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:49.467669  6754 feature_extraction.cc:280]   Features:        10882
# I1120 18:22:49.590026  6754 feature_extraction.cc:258] Processed file [13/254]
# I1120 18:22:49.590057  6754 feature_extraction.cc:261]   Name:            P1370844.JPG
# I1120 18:22:49.590061  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:49.590065  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:49.590068  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:49.590083  6754 feature_extraction.cc:280]   Features:        9004
# I1120 18:22:50.104419  6754 feature_extraction.cc:258] Processed file [14/254]
# I1120 18:22:50.104449  6754 feature_extraction.cc:261]   Name:            P1370845.JPG
# I1120 18:22:50.104454  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:50.104456  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:50.104460  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:50.104470  6754 feature_extraction.cc:280]   Features:        9779
# I1120 18:22:50.135960  6754 feature_extraction.cc:258] Processed file [15/254]
# I1120 18:22:50.135998  6754 feature_extraction.cc:261]   Name:            P1370846.JPG
# I1120 18:22:50.136003  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:50.136008  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:50.136013  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:50.136023  6754 feature_extraction.cc:280]   Features:        9555
# I1120 18:22:51.257833  6754 feature_extraction.cc:258] Processed file [16/254]
# I1120 18:22:51.257866  6754 feature_extraction.cc:261]   Name:            P1370847.JPG
# I1120 18:22:51.257871  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:51.257874  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:51.257879  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:51.257887  6754 feature_extraction.cc:280]   Features:        9884
# I1120 18:22:51.294447  6754 feature_extraction.cc:258] Processed file [17/254]
# I1120 18:22:51.294478  6754 feature_extraction.cc:261]   Name:            P1370848.JPG
# I1120 18:22:51.294482  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:51.294486  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:51.294495  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:51.294507  6754 feature_extraction.cc:280]   Features:        12107
# I1120 18:22:54.128561  6754 feature_extraction.cc:258] Processed file [18/254]
# I1120 18:22:54.128592  6754 feature_extraction.cc:261]   Name:            P1370849.JPG
# I1120 18:22:54.128595  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:54.128598  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:54.128602  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:54.128621  6754 feature_extraction.cc:280]   Features:        9798
# I1120 18:22:54.266535  6754 feature_extraction.cc:258] Processed file [19/254]
# I1120 18:22:54.266578  6754 feature_extraction.cc:261]   Name:            P1370850.JPG
# I1120 18:22:54.266584  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:54.266594  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:54.266600  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:54.266618  6754 feature_extraction.cc:280]   Features:        6902
# I1120 18:22:55.635656  6754 feature_extraction.cc:258] Processed file [20/254]
# I1120 18:22:55.635685  6754 feature_extraction.cc:261]   Name:            P1370851.JPG
# I1120 18:22:55.635690  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:55.635694  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:55.635699  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:55.635710  6754 feature_extraction.cc:280]   Features:        9154
# I1120 18:22:55.669872  6754 feature_extraction.cc:258] Processed file [21/254]
# I1120 18:22:55.669904  6754 feature_extraction.cc:261]   Name:            P1370852.JPG
# I1120 18:22:55.669909  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:55.669914  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:55.669919  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:55.669929  6754 feature_extraction.cc:280]   Features:        10494
# I1120 18:22:57.134773  6754 feature_extraction.cc:258] Processed file [22/254]
# I1120 18:22:57.134806  6754 feature_extraction.cc:261]   Name:            P1370853.JPG
# I1120 18:22:57.134810  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:57.134814  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:57.134817  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:57.134826  6754 feature_extraction.cc:280]   Features:        9320
# I1120 18:22:57.171344  6754 feature_extraction.cc:258] Processed file [23/254]
# I1120 18:22:57.171372  6754 feature_extraction.cc:261]   Name:            P1370854.JPG
# I1120 18:22:57.171376  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:57.171379  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:57.171383  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:57.171391  6754 feature_extraction.cc:280]   Features:        9701
# I1120 18:22:58.890188  6754 feature_extraction.cc:258] Processed file [24/254]
# I1120 18:22:58.890219  6754 feature_extraction.cc:261]   Name:            P1370855.JPG
# I1120 18:22:58.890225  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:58.890229  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:58.890234  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:58.890246  6754 feature_extraction.cc:280]   Features:        8099
# I1120 18:22:58.983584  6754 feature_extraction.cc:258] Processed file [25/254]
# I1120 18:22:58.983618  6754 feature_extraction.cc:261]   Name:            P1370856.JPG
# I1120 18:22:58.983628  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:22:58.983636  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:22:58.983645  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:22:58.983661  6754 feature_extraction.cc:280]   Features:        9034
# I1120 18:23:01.889034  6754 feature_extraction.cc:258] Processed file [26/254]
# I1120 18:23:01.889068  6754 feature_extraction.cc:261]   Name:            P1370857.JPG
# I1120 18:23:01.889075  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:01.889079  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:01.889089  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:01.889110  6754 feature_extraction.cc:280]   Features:        11116
# I1120 18:23:01.939164  6754 feature_extraction.cc:258] Processed file [27/254]
# I1120 18:23:01.939199  6754 feature_extraction.cc:261]   Name:            P1370858.JPG
# I1120 18:23:01.939205  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:01.939210  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:01.939216  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:01.939229  6754 feature_extraction.cc:280]   Features:        10277
# I1120 18:23:03.576077  6754 feature_extraction.cc:258] Processed file [28/254]
# I1120 18:23:03.576118  6754 feature_extraction.cc:261]   Name:            P1370859.JPG
# I1120 18:23:03.576128  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:03.576134  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:03.576149  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:03.576172  6754 feature_extraction.cc:280]   Features:        11500
# I1120 18:23:04.153966  6754 feature_extraction.cc:258] Processed file [29/254]
# I1120 18:23:04.153999  6754 feature_extraction.cc:261]   Name:            P1370860.JPG
# I1120 18:23:04.154003  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:04.154006  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:04.154011  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:04.154021  6754 feature_extraction.cc:280]   Features:        9855
# I1120 18:23:04.201140  6754 feature_extraction.cc:258] Processed file [30/254]
# I1120 18:23:04.201177  6754 feature_extraction.cc:261]   Name:            P1370861.JPG
# I1120 18:23:04.201184  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:04.201188  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:04.201193  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:04.201205  6754 feature_extraction.cc:280]   Features:        11317
# I1120 18:23:04.813390  6754 feature_extraction.cc:258] Processed file [31/254]
# I1120 18:23:04.813437  6754 feature_extraction.cc:261]   Name:            P1370862.JPG
# I1120 18:23:04.813441  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:04.813445  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:04.813449  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:04.813458  6754 feature_extraction.cc:280]   Features:        8204
# I1120 18:23:04.841918  6754 feature_extraction.cc:258] Processed file [32/254]
# I1120 18:23:04.841946  6754 feature_extraction.cc:261]   Name:            P1370863.JPG
# I1120 18:23:04.841950  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:04.841953  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:04.841957  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:04.841969  6754 feature_extraction.cc:280]   Features:        8948
# I1120 18:23:06.597522  6754 feature_extraction.cc:258] Processed file [33/254]
# I1120 18:23:06.597564  6754 feature_extraction.cc:261]   Name:            P1370864.JPG
# I1120 18:23:06.597570  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:06.597576  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:06.597585  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:06.597596  6754 feature_extraction.cc:280]   Features:        9964
# I1120 18:23:06.705677  6754 feature_extraction.cc:258] Processed file [34/254]
# I1120 18:23:06.705708  6754 feature_extraction.cc:261]   Name:            P1370865.JPG
# I1120 18:23:06.705711  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:06.705714  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:06.705718  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:06.705729  6754 feature_extraction.cc:280]   Features:        9944
# I1120 18:23:08.422258  6754 feature_extraction.cc:258] Processed file [35/254]
# I1120 18:23:08.422291  6754 feature_extraction.cc:261]   Name:            P1370866.JPG
# I1120 18:23:08.422294  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:08.422297  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:08.422302  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:08.422312  6754 feature_extraction.cc:280]   Features:        8654
# I1120 18:23:08.450053  6754 feature_extraction.cc:258] Processed file [36/254]
# I1120 18:23:08.450085  6754 feature_extraction.cc:261]   Name:            P1370867.JPG
# I1120 18:23:08.450093  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:08.450096  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:08.450102  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:08.450114  6754 feature_extraction.cc:280]   Features:        8237
# I1120 18:23:10.259152  6754 feature_extraction.cc:258] Processed file [37/254]
# I1120 18:23:10.259191  6754 feature_extraction.cc:261]   Name:            P1370868.JPG
# I1120 18:23:10.259198  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:10.259202  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:10.259213  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:10.259228  6754 feature_extraction.cc:280]   Features:        5584
# I1120 18:23:10.281895  6754 feature_extraction.cc:258] Processed file [38/254]
# I1120 18:23:10.281932  6754 feature_extraction.cc:261]   Name:            P1370869.JPG
# I1120 18:23:10.281937  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:10.281944  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:10.281949  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:10.281962  6754 feature_extraction.cc:280]   Features:        8260
# I1120 18:23:10.782410  6754 feature_extraction.cc:258] Processed file [39/254]
# I1120 18:23:10.782455  6754 feature_extraction.cc:261]   Name:            P1370870.JPG
# I1120 18:23:10.782464  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:10.782466  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:10.782470  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:10.782480  6754 feature_extraction.cc:280]   Features:        7230
# I1120 18:23:10.804824  6754 feature_extraction.cc:258] Processed file [40/254]
# I1120 18:23:10.804855  6754 feature_extraction.cc:261]   Name:            P1370871.JPG
# I1120 18:23:10.804859  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:10.804862  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:10.804867  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:10.804874  6754 feature_extraction.cc:280]   Features:        3500
# I1120 18:23:11.290184  6754 feature_extraction.cc:258] Processed file [41/254]
# I1120 18:23:11.290212  6754 feature_extraction.cc:261]   Name:            P1370872.JPG
# I1120 18:23:11.290216  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:11.290220  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:11.290223  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:11.290232  6754 feature_extraction.cc:280]   Features:        4183
# I1120 18:23:11.374022  6754 feature_extraction.cc:258] Processed file [42/254]
# I1120 18:23:11.374059  6754 feature_extraction.cc:261]   Name:            P1370873.JPG
# I1120 18:23:11.374065  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:11.374070  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:11.374075  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:11.374091  6754 feature_extraction.cc:280]   Features:        6797
# I1120 18:23:13.027318  6754 feature_extraction.cc:258] Processed file [43/254]
# I1120 18:23:13.027347  6754 feature_extraction.cc:261]   Name:            P1370874.JPG
# I1120 18:23:13.027351  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:13.027356  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:13.027366  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:13.027381  6754 feature_extraction.cc:280]   Features:        10263
# I1120 18:23:13.064908  6754 feature_extraction.cc:258] Processed file [44/254]
# I1120 18:23:13.064944  6754 feature_extraction.cc:261]   Name:            P1370875.JPG
# I1120 18:23:13.064949  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:13.064953  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:13.064960  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:13.064973  6754 feature_extraction.cc:280]   Features:        8715
# I1120 18:23:15.872267  6754 feature_extraction.cc:258] Processed file [45/254]
# I1120 18:23:15.872300  6754 feature_extraction.cc:261]   Name:            P1370876.JPG
# I1120 18:23:15.872304  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:15.872308  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:15.872311  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:15.872321  6754 feature_extraction.cc:280]   Features:        13295
# I1120 18:23:16.014436  6754 feature_extraction.cc:258] Processed file [46/254]
# I1120 18:23:16.014467  6754 feature_extraction.cc:261]   Name:            P1370877.JPG
# I1120 18:23:16.014472  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:16.014477  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:16.014480  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:16.014488  6754 feature_extraction.cc:280]   Features:        11547
# I1120 18:23:16.516626  6754 feature_extraction.cc:258] Processed file [47/254]
# I1120 18:23:16.516657  6754 feature_extraction.cc:261]   Name:            P1370878.JPG
# I1120 18:23:16.516664  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:16.516669  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:16.516674  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:16.516686  6754 feature_extraction.cc:280]   Features:        10702
# I1120 18:23:16.569236  6754 feature_extraction.cc:258] Processed file [48/254]
# I1120 18:23:16.569267  6754 feature_extraction.cc:261]   Name:            P1370879.JPG
# I1120 18:23:16.569270  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:16.569273  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:16.569278  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:16.569286  6754 feature_extraction.cc:280]   Features:        10005
# I1120 18:23:18.509106  6754 feature_extraction.cc:258] Processed file [49/254]
# I1120 18:23:18.509136  6754 feature_extraction.cc:261]   Name:            P1370880.JPG
# I1120 18:23:18.509140  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:18.509145  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:18.509147  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:18.509158  6754 feature_extraction.cc:280]   Features:        11112
# I1120 18:23:18.545909  6754 feature_extraction.cc:258] Processed file [50/254]
# I1120 18:23:18.545936  6754 feature_extraction.cc:261]   Name:            P1370881.JPG
# I1120 18:23:18.545940  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:18.545948  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:18.545953  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:18.545964  6754 feature_extraction.cc:280]   Features:        6500
# I1120 18:23:19.052739  6754 feature_extraction.cc:258] Processed file [51/254]
# I1120 18:23:19.052767  6754 feature_extraction.cc:261]   Name:            P1370882.JPG
# I1120 18:23:19.052771  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:19.052774  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:19.052778  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:19.052790  6754 feature_extraction.cc:280]   Features:        9561
# I1120 18:23:19.151173  6754 feature_extraction.cc:258] Processed file [52/254]
# I1120 18:23:19.151208  6754 feature_extraction.cc:261]   Name:            P1370883.JPG
# I1120 18:23:19.151214  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:19.151218  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:19.151223  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:19.151238  6754 feature_extraction.cc:280]   Features:        10462
# I1120 18:23:19.656185  6754 feature_extraction.cc:258] Processed file [53/254]
# I1120 18:23:19.656214  6754 feature_extraction.cc:261]   Name:            P1370884.JPG
# I1120 18:23:19.656222  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:19.656226  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:19.656230  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:19.656239  6754 feature_extraction.cc:280]   Features:        12867
# I1120 18:23:19.696065  6754 feature_extraction.cc:258] Processed file [54/254]
# I1120 18:23:19.696096  6754 feature_extraction.cc:261]   Name:            P1370885.JPG
# I1120 18:23:19.696099  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:19.696102  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:19.696106  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:19.696116  6754 feature_extraction.cc:280]   Features:        9669
# I1120 18:23:22.316179  6754 feature_extraction.cc:258] Processed file [55/254]
# I1120 18:23:22.316215  6754 feature_extraction.cc:261]   Name:            P1370886.JPG
# I1120 18:23:22.316219  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:22.316222  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:22.316226  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:22.316236  6754 feature_extraction.cc:280]   Features:        8716
# I1120 18:23:22.354081  6754 feature_extraction.cc:258] Processed file [56/254]
# I1120 18:23:22.354112  6754 feature_extraction.cc:261]   Name:            P1370887.JPG
# I1120 18:23:22.354116  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:22.354120  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:22.354123  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:22.354132  6754 feature_extraction.cc:280]   Features:        9159
# I1120 18:23:22.436057  6754 feature_extraction.cc:258] Processed file [57/254]
# I1120 18:23:22.436093  6754 feature_extraction.cc:261]   Name:            P1370888.JPG
# I1120 18:23:22.436097  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:22.436100  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:22.436105  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:22.436115  6754 feature_extraction.cc:280]   Features:        7864
# I1120 18:23:24.134356  6754 feature_extraction.cc:258] Processed file [58/254]
# I1120 18:23:24.134387  6754 feature_extraction.cc:261]   Name:            P1370889.JPG
# I1120 18:23:24.134390  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:24.134393  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:24.134397  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:24.134411  6754 feature_extraction.cc:280]   Features:        3142
# I1120 18:23:24.212492  6754 feature_extraction.cc:258] Processed file [59/254]
# I1120 18:23:24.212529  6754 feature_extraction.cc:261]   Name:            P1370890.JPG
# I1120 18:23:24.212536  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:24.212541  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:24.212558  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:24.212572  6754 feature_extraction.cc:280]   Features:        5683
# I1120 18:23:26.002168  6754 feature_extraction.cc:258] Processed file [60/254]
# I1120 18:23:26.002197  6754 feature_extraction.cc:261]   Name:            P1370891.JPG
# I1120 18:23:26.002202  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:26.002207  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:26.002213  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:26.002228  6754 feature_extraction.cc:280]   Features:        8782
# I1120 18:23:26.042141  6754 feature_extraction.cc:258] Processed file [61/254]
# I1120 18:23:26.042177  6754 feature_extraction.cc:261]   Name:            P1370892.JPG
# I1120 18:23:26.042183  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:26.042188  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:26.042193  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:26.042207  6754 feature_extraction.cc:280]   Features:        2349
# I1120 18:23:27.757728  6754 feature_extraction.cc:258] Processed file [62/254]
# I1120 18:23:27.757756  6754 feature_extraction.cc:261]   Name:            P1370893.JPG
# I1120 18:23:27.757761  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:27.757763  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:27.757766  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:27.757778  6754 feature_extraction.cc:280]   Features:        6368
# I1120 18:23:27.783548  6754 feature_extraction.cc:258] Processed file [63/254]
# I1120 18:23:27.783591  6754 feature_extraction.cc:261]   Name:            P1370894.JPG
# I1120 18:23:27.783596  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:27.783605  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:27.783612  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:27.783627  6754 feature_extraction.cc:280]   Features:        7526
# I1120 18:23:28.361368  6754 feature_extraction.cc:258] Processed file [64/254]
# I1120 18:23:28.361400  6754 feature_extraction.cc:261]   Name:            P1370895.JPG
# I1120 18:23:28.361418  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:28.361420  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:28.361424  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:28.361434  6754 feature_extraction.cc:280]   Features:        4414
# I1120 18:23:28.381322  6754 feature_extraction.cc:258] Processed file [65/254]
# I1120 18:23:28.381363  6754 feature_extraction.cc:261]   Name:            P1370896.JPG
# I1120 18:23:28.381369  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:28.381373  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:28.381385  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:28.381400  6754 feature_extraction.cc:280]   Features:        6926
# I1120 18:23:30.164193  6754 feature_extraction.cc:258] Processed file [66/254]
# I1120 18:23:30.164223  6754 feature_extraction.cc:261]   Name:            P1370897.JPG
# I1120 18:23:30.164227  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:30.164230  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:30.164234  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:30.164247  6754 feature_extraction.cc:280]   Features:        9646
# I1120 18:23:30.196906  6754 feature_extraction.cc:258] Processed file [67/254]
# I1120 18:23:30.196934  6754 feature_extraction.cc:261]   Name:            P1370898.JPG
# I1120 18:23:30.196938  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:30.196941  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:30.196946  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:30.196957  6754 feature_extraction.cc:280]   Features:        9764
# I1120 18:23:30.306187  6754 feature_extraction.cc:258] Processed file [68/254]
# I1120 18:23:30.306228  6754 feature_extraction.cc:261]   Name:            P1370899.JPG
# I1120 18:23:30.306237  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:30.306242  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:30.306248  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:30.306260  6754 feature_extraction.cc:280]   Features:        12510
# I1120 18:23:32.267060  6754 feature_extraction.cc:258] Processed file [69/254]
# I1120 18:23:32.267089  6754 feature_extraction.cc:261]   Name:            P1370900.JPG
# I1120 18:23:32.267094  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:32.267097  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:32.267102  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:32.267114  6754 feature_extraction.cc:280]   Features:        7779
# I1120 18:23:32.305672  6754 feature_extraction.cc:258] Processed file [70/254]
# I1120 18:23:32.305708  6754 feature_extraction.cc:261]   Name:            P1370901.JPG
# I1120 18:23:32.305714  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:32.305718  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:32.305723  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:32.305735  6754 feature_extraction.cc:280]   Features:        12022
# I1120 18:23:32.915037  6754 feature_extraction.cc:258] Processed file [71/254]
# I1120 18:23:32.915069  6754 feature_extraction.cc:261]   Name:            P1370902.JPG
# I1120 18:23:32.915072  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:32.915076  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:32.915079  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:32.915089  6754 feature_extraction.cc:280]   Features:        11766
# I1120 18:23:32.954252  6754 feature_extraction.cc:258] Processed file [72/254]
# I1120 18:23:32.954282  6754 feature_extraction.cc:261]   Name:            P1370903.JPG
# I1120 18:23:32.954286  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:32.954289  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:32.954293  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:32.954309  6754 feature_extraction.cc:280]   Features:        8205
# I1120 18:23:34.060344  6754 feature_extraction.cc:258] Processed file [73/254]
# I1120 18:23:34.060379  6754 feature_extraction.cc:261]   Name:            P1370904.JPG
# I1120 18:23:34.060382  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:34.060397  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:34.060401  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:34.060410  6754 feature_extraction.cc:280]   Features:        8454
# I1120 18:23:34.158046  6754 feature_extraction.cc:258] Processed file [74/254]
# I1120 18:23:34.158082  6754 feature_extraction.cc:261]   Name:            P1370905.JPG
# I1120 18:23:34.158088  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:34.158093  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:34.158099  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:34.158111  6754 feature_extraction.cc:280]   Features:        4814
# I1120 18:23:34.648638  6754 feature_extraction.cc:258] Processed file [75/254]
# I1120 18:23:34.648664  6754 feature_extraction.cc:261]   Name:            P1370906.JPG
# I1120 18:23:34.648669  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:34.648671  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:34.648675  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:34.648689  6754 feature_extraction.cc:280]   Features:        8494
# I1120 18:23:34.676832  6754 feature_extraction.cc:258] Processed file [76/254]
# I1120 18:23:34.676862  6754 feature_extraction.cc:261]   Name:            P1370907.JPG
# I1120 18:23:34.676864  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:34.676867  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:34.676872  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:34.676885  6754 feature_extraction.cc:280]   Features:        9275
# I1120 18:23:36.556475  6754 feature_extraction.cc:258] Processed file [77/254]
# I1120 18:23:36.556507  6754 feature_extraction.cc:261]   Name:            P1370908.JPG
# I1120 18:23:36.556537  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:36.556541  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:36.556545  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:36.556572  6754 feature_extraction.cc:280]   Features:        4481
# I1120 18:23:36.634354  6754 feature_extraction.cc:258] Processed file [78/254]
# I1120 18:23:36.634382  6754 feature_extraction.cc:261]   Name:            P1370909.JPG
# I1120 18:23:36.634390  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:36.634394  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:36.634404  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:36.634420  6754 feature_extraction.cc:280]   Features:        9416
# I1120 18:23:37.139137  6754 feature_extraction.cc:258] Processed file [79/254]
# I1120 18:23:37.139166  6754 feature_extraction.cc:261]   Name:            P1370910.JPG
# I1120 18:23:37.139170  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:37.139173  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:37.139178  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:37.139187  6754 feature_extraction.cc:280]   Features:        8429
# I1120 18:23:37.174798  6754 feature_extraction.cc:258] Processed file [80/254]
# I1120 18:23:37.174829  6754 feature_extraction.cc:261]   Name:            P1370911.JPG
# I1120 18:23:37.174831  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:37.174834  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:37.174839  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:37.174850  6754 feature_extraction.cc:280]   Features:        9307
# I1120 18:23:37.739403  6754 feature_extraction.cc:258] Processed file [81/254]
# I1120 18:23:37.739434  6754 feature_extraction.cc:261]   Name:            P1370912.JPG
# I1120 18:23:37.739440  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:37.739445  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:37.739450  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:37.739462  6754 feature_extraction.cc:280]   Features:        2758
# I1120 18:23:37.748311  6754 feature_extraction.cc:258] Processed file [82/254]
# I1120 18:23:37.748340  6754 feature_extraction.cc:261]   Name:            P1370913.JPG
# I1120 18:23:37.748348  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:37.748353  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:37.748358  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:37.748370  6754 feature_extraction.cc:280]   Features:        5966
# I1120 18:23:38.258742  6754 feature_extraction.cc:258] Processed file [83/254]
# I1120 18:23:38.258771  6754 feature_extraction.cc:261]   Name:            P1370914.JPG
# I1120 18:23:38.258775  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:38.258778  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:38.258788  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:38.258800  6754 feature_extraction.cc:280]   Features:        9646
# I1120 18:23:38.299378  6754 feature_extraction.cc:258] Processed file [84/254]
# I1120 18:23:38.299413  6754 feature_extraction.cc:261]   Name:            P1370915.JPG
# I1120 18:23:38.299418  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:38.299423  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:38.299434  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:38.299448  6754 feature_extraction.cc:280]   Features:        2597
# I1120 18:23:40.071677  6754 feature_extraction.cc:258] Processed file [85/254]
# I1120 18:23:40.071705  6754 feature_extraction.cc:261]   Name:            P1370916.JPG
# I1120 18:23:40.071708  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:40.071729  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:40.071733  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:40.071743  6754 feature_extraction.cc:280]   Features:        10615
# I1120 18:23:40.194432  6754 feature_extraction.cc:258] Processed file [86/254]
# I1120 18:23:40.194463  6754 feature_extraction.cc:261]   Name:            P1370917.JPG
# I1120 18:23:40.194473  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:40.194478  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:40.194484  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:40.194496  6754 feature_extraction.cc:280]   Features:        12539
# I1120 18:23:40.725051  6754 feature_extraction.cc:258] Processed file [87/254]
# I1120 18:23:40.725090  6754 feature_extraction.cc:261]   Name:            P1370918.JPG
# I1120 18:23:40.725100  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:40.725106  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:40.725114  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:40.725139  6754 feature_extraction.cc:280]   Features:        8042
# I1120 18:23:40.755548  6754 feature_extraction.cc:258] Processed file [88/254]
# I1120 18:23:40.755592  6754 feature_extraction.cc:261]   Name:            P1370919.JPG
# I1120 18:23:40.755597  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:40.755602  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:40.755609  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:40.755620  6754 feature_extraction.cc:280]   Features:        9885
# I1120 18:23:41.353035  6754 feature_extraction.cc:258] Processed file [89/254]
# I1120 18:23:41.353068  6754 feature_extraction.cc:261]   Name:            P1370920.JPG
# I1120 18:23:41.353072  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:41.353076  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:41.353080  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:41.353103  6754 feature_extraction.cc:280]   Features:        8408
# I1120 18:23:41.380834  6754 feature_extraction.cc:258] Processed file [90/254]
# I1120 18:23:41.380865  6754 feature_extraction.cc:261]   Name:            P1370921.JPG
# I1120 18:23:41.380869  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:41.380872  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:41.380877  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:41.380887  6754 feature_extraction.cc:280]   Features:        1776
# I1120 18:23:41.874372  6754 feature_extraction.cc:258] Processed file [91/254]
# I1120 18:23:41.874403  6754 feature_extraction.cc:261]   Name:            P1370922.JPG
# I1120 18:23:41.874408  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:41.874410  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:41.874414  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:41.874423  6754 feature_extraction.cc:280]   Features:        6788
# I1120 18:23:41.900188  6754 feature_extraction.cc:258] Processed file [92/254]
# I1120 18:23:41.900224  6754 feature_extraction.cc:261]   Name:            P1370923.JPG
# I1120 18:23:41.900229  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:41.900233  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:41.900239  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:41.900250  6754 feature_extraction.cc:280]   Features:        3602
# I1120 18:23:42.387470  6754 feature_extraction.cc:258] Processed file [93/254]
# I1120 18:23:42.387499  6754 feature_extraction.cc:261]   Name:            P1370924.JPG
# I1120 18:23:42.387503  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# I1120 18:23:42.387506  6754 feature_extraction.cc:273]   Camera:          #1 - OPENCV
# I1120 18:23:42.387511  6754 feature_extraction.cc:276]   Focal Length:    3908.57px (Prior)
# I1120 18:23:42.387524  6754 feature_extraction.cc:280]   Features:        1965
# I1120 18:23:42.394008  6754 feature_extraction.cc:258] Processed file [94/254]
# I1120 18:23:42.394034  6754 feature_extraction.cc:261]   Name:            P1370925.JPG
# I1120 18:23:42.394037  6754 feature_extraction.cc:270]   Dimensions:      5472 x 3648
# ...
# I1120 18:59:03.480984 16648 undistortion.cc:215] Undistorting image [52/252]
# I1120 18:59:03.580526 16648 undistortion.cc:215] Undistorting image [53/252]
# I1120 18:59:03.866919 16648 undistortion.cc:215] Undistorting image [54/252]
# I1120 18:59:04.087792 16648 undistortion.cc:215] Undistorting image [55/252]
# I1120 18:59:04.087829 16648 undistortion.cc:215] Undistorting image [56/252]
# I1120 18:59:04.309070 16648 undistortion.cc:215] Undistorting image [57/252]
# I1120 18:59:09.720309 16648 undistortion.cc:215] Undistorting image [58/252]
# I1120 18:59:09.953801 16648 undistortion.cc:215] Undistorting image [59/252]
# I1120 18:59:10.892230 16648 undistortion.cc:215] Undistorting image [60/252]
# I1120 18:59:10.892275 16648 undistortion.cc:215] Undistorting image [61/252]
# I1120 18:59:11.601747 16648 undistortion.cc:215] Undistorting image [62/252]
# I1120 18:59:11.909302 16648 undistortion.cc:215] Undistorting image [63/252]
# I1120 18:59:11.909345 16648 undistortion.cc:215] Undistorting image [64/252]
# I1120 18:59:11.917588 16648 undistortion.cc:215] Undistorting image [65/252]
# I1120 18:59:16.727424 16648 undistortion.cc:215] Undistorting image [66/252]
# I1120 18:59:16.937929 16648 undistortion.cc:215] Undistorting image [67/252]
# I1120 18:59:18.148360 16648 undistortion.cc:215] Undistorting image [68/252]
# I1120 18:59:18.172683 16648 undistortion.cc:215] Undistorting image [69/252]
# I1120 18:59:18.968055 16648 undistortion.cc:215] Undistorting image [70/252]
# I1120 18:59:19.048628 16648 undistortion.cc:215] Undistorting image [71/252]
# I1120 18:59:19.422320 16648 undistortion.cc:215] Undistorting image [72/252]
# I1120 18:59:19.588973 16648 undistortion.cc:215] Undistorting image [73/252]
# I1120 18:59:24.361238 16648 undistortion.cc:215] Undistorting image [74/252]
# I1120 18:59:24.482947 16648 undistortion.cc:215] Undistorting image [75/252]
# I1120 18:59:25.269922 16648 undistortion.cc:215] Undistorting image [76/252]
# I1120 18:59:25.522712 16648 undistortion.cc:215] Undistorting image [77/252]
# I1120 18:59:26.083143 16648 undistortion.cc:215] Undistorting image [78/252]
# I1120 18:59:26.605888 16648 undistortion.cc:215] Undistorting image [79/252]
# I1120 18:59:26.605931 16648 undistortion.cc:215] Undistorting image [80/252]
# I1120 18:59:26.783596 16648 undistortion.cc:215] Undistorting image [81/252]
# I1120 18:59:31.143532 16648 undistortion.cc:215] Undistorting image [82/252]
# I1120 18:59:31.399914 16648 undistortion.cc:215] Undistorting image [83/252]
# I1120 18:59:32.402498 16648 undistortion.cc:215] Undistorting image [84/252]
# I1120 18:59:32.834839 16648 undistortion.cc:215] Undistorting image [85/252]
# I1120 18:59:33.458273 16648 undistortion.cc:215] Undistorting image [86/252]
# I1120 18:59:33.966540 16648 undistortion.cc:215] Undistorting image [87/252]
# I1120 18:59:34.082862 16648 undistortion.cc:215] Undistorting image [88/252]
# I1120 18:59:34.316716 16648 undistortion.cc:215] Undistorting image [89/252]
# I1120 18:59:38.106941 16648 undistortion.cc:215] Undistorting image [90/252]
# I1120 18:59:38.468560 16648 undistortion.cc:215] Undistorting image [91/252]
# I1120 18:59:39.535614 16648 undistortion.cc:215] Undistorting image [92/252]
# I1120 18:59:39.888592 16648 undistortion.cc:215] Undistorting image [93/252]
# I1120 18:59:40.584363 16648 undistortion.cc:215] Undistorting image [94/252]
# I1120 18:59:41.095239 16648 undistortion.cc:215] Undistorting image [95/252]
# I1120 18:59:41.186291 16648 undistortion.cc:215] Undistorting image [96/252]
# I1120 18:59:41.636143 16648 undistortion.cc:215] Undistorting image [97/252]
# I1120 18:59:44.945423 16648 undistortion.cc:215] Undistorting image [98/252]
# I1120 18:59:45.450306 16648 undistortion.cc:215] Undistorting image [99/252]
# I1120 18:59:46.513442 16648 undistortion.cc:215] Undistorting image [100/252]
# I1120 18:59:47.307255 16648 undistortion.cc:215] Undistorting image [101/252]
# I1120 18:59:47.987607 16648 undistortion.cc:215] Undistorting image [102/252]
# I1120 18:59:48.322221 16648 undistortion.cc:215] Undistorting image [103/252]
# I1120 18:59:49.100692 16648 undistortion.cc:215] Undistorting image [104/252]
# I1120 18:59:49.211922 16648 undistortion.cc:215] Undistorting image [105/252]
# I1120 18:59:52.137866 16648 undistortion.cc:215] Undistorting image [106/252]
# I1120 18:59:52.562068 16648 undistortion.cc:215] Undistorting image [107/252]
# I1120 18:59:53.695405 16648 undistortion.cc:215] Undistorting image [108/252]
# I1120 18:59:54.560797 16648 undistortion.cc:215] Undistorting image [109/252]
# I1120 18:59:54.829005 16648 undistortion.cc:215] Undistorting image [110/252]
# I1120 18:59:55.686947 16648 undistortion.cc:215] Undistorting image [111/252]
# I1120 18:59:56.045397 16648 undistortion.cc:215] Undistorting image [112/252]
# I1120 18:59:56.330884 16648 undistortion.cc:215] Undistorting image [113/252]
# I1120 18:59:58.933521 16648 undistortion.cc:215] Undistorting image [114/252]
# I1120 18:59:59.334300 16648 undistortion.cc:215] Undistorting image [115/252]
# I1120 19:00:00.799335 16648 undistortion.cc:215] Undistorting image [116/252]
# I1120 19:00:01.946674 16648 undistortion.cc:215] Undistorting image [117/252]
# I1120 19:00:02.071667 16648 undistortion.cc:215] Undistorting image [118/252]
# I1120 19:00:03.145704 16648 undistortion.cc:215] Undistorting image [119/252]
# I1120 19:00:03.270828 16648 undistortion.cc:215] Undistorting image [120/252]
# I1120 19:00:03.798915 16648 undistortion.cc:215] Undistorting image [121/252]
# I1120 19:00:06.340517 16648 undistortion.cc:215] Undistorting image [122/252]
# I1120 19:00:07.230443 16648 undistortion.cc:215] Undistorting image [123/252]
# I1120 19:00:08.362679 16648 undistortion.cc:215] Undistorting image [124/252]
# I1120 19:00:09.464485 16648 undistortion.cc:215] Undistorting image [125/252]
# I1120 19:00:09.620319 16648 undistortion.cc:215] Undistorting image [126/252]
# I1120 19:00:10.813174 16648 undistortion.cc:215] Undistorting image [127/252]
# I1120 19:00:10.813215 16648 undistortion.cc:215] Undistorting image [128/252]
# I1120 19:00:11.474653 16648 undistortion.cc:215] Undistorting image [129/252]
# I1120 19:00:13.736368 16648 undistortion.cc:215] Undistorting image [130/252]
# I1120 19:00:14.563704 16648 undistortion.cc:215] Undistorting image [131/252]
# I1120 19:00:15.566015 16648 undistortion.cc:215] Undistorting image [132/252]
# I1120 19:00:16.582808 16648 undistortion.cc:215] Undistorting image [133/252]
# I1120 19:00:17.022354 16648 undistortion.cc:215] Undistorting image [134/252]
# I1120 19:00:18.296097 16648 undistortion.cc:215] Undistorting image [135/252]
# I1120 19:00:18.313649 16648 undistortion.cc:215] Undistorting image [136/252]
# I1120 19:00:18.720244 16648 undistortion.cc:215] Undistorting image [137/252]
# I1120 19:00:20.953768 16648 undistortion.cc:215] Undistorting image [138/252]
# I1120 19:00:21.613741 16648 undistortion.cc:215] Undistorting image [139/252]
# I1120 19:00:22.783229 16648 undistortion.cc:215] Undistorting image [140/252]
# I1120 19:00:23.536995 16648 undistortion.cc:215] Undistorting image [141/252]
# I1120 19:00:23.791455 16648 undistortion.cc:215] Undistorting image [142/252]
# I1120 19:00:25.103394 16648 undistortion.cc:215] Undistorting image [143/252]
# I1120 19:00:25.389310 16648 undistortion.cc:215] Undistorting image [144/252]
# I1120 19:00:25.550824 16648 undistortion.cc:215] Undistorting image [145/252]
# I1120 19:00:27.737767 16648 undistortion.cc:215] Undistorting image [146/252]
# I1120 19:00:28.319834 16648 undistortion.cc:215] Undistorting image [147/252]
# I1120 19:00:30.080591 16648 undistortion.cc:215] Undistorting image [148/252]
# I1120 19:00:30.634286 16648 undistortion.cc:215] Undistorting image [149/252]
# I1120 19:00:31.023195 16648 undistortion.cc:215] Undistorting image [150/252]
# I1120 19:00:32.624797 16648 undistortion.cc:215] Undistorting image [151/252]
# I1120 19:00:32.741241 16648 undistortion.cc:215] Undistorting image [152/252]
# I1120 19:00:32.741278 16648 undistortion.cc:215] Undistorting image [153/252]
# I1120 19:00:35.076936 16648 undistortion.cc:215] Undistorting image [154/252]
# I1120 19:00:35.431304 16648 undistortion.cc:215] Undistorting image [155/252]
# I1120 19:00:36.962752 16648 undistortion.cc:215] Undistorting image [156/252]
# I1120 19:00:37.625084 16648 undistortion.cc:215] Undistorting image [157/252]
# I1120 19:00:37.952509 16648 undistortion.cc:215] Undistorting image [158/252]
# I1120 19:00:39.347354 16648 undistortion.cc:215] Undistorting image [159/252]
# I1120 19:00:39.577803 16648 undistortion.cc:215] Undistorting image [160/252]
# I1120 19:00:39.577841 16648 undistortion.cc:215] Undistorting image [161/252]
# I1120 19:00:41.786574 16648 undistortion.cc:215] Undistorting image [162/252]
# I1120 19:00:42.225148 16648 undistortion.cc:215] Undistorting image [163/252]
# I1120 19:00:44.441757 16648 undistortion.cc:215] Undistorting image [164/252]
# I1120 19:00:45.161468 16648 undistortion.cc:215] Undistorting image [165/252]
# I1120 19:00:45.161547 16648 undistortion.cc:215] Undistorting image [166/252]
# I1120 19:00:46.756117 16648 undistortion.cc:215] Undistorting image [167/252]
# I1120 19:00:46.819169 16648 undistortion.cc:215] Undistorting image [168/252]
# I1120 19:00:47.080520 16648 undistortion.cc:215] Undistorting image [169/252]
# I1120 19:00:49.244906 16648 undistortion.cc:215] Undistorting image [170/252]
# I1120 19:00:49.603523 16648 undistortion.cc:215] Undistorting image [171/252]
# I1120 19:00:51.492017 16648 undistortion.cc:215] Undistorting image [172/252]
# I1120 19:00:52.103813 16648 undistortion.cc:215] Undistorting image [173/252]
# I1120 19:00:52.103861 16648 undistortion.cc:215] Undistorting image [174/252]
# I1120 19:00:53.844621 16648 undistortion.cc:215] Undistorting image [175/252]
# I1120 19:00:53.844668 16648 undistortion.cc:215] Undistorting image [176/252]
# I1120 19:00:54.167984 16648 undistortion.cc:215] Undistorting image [177/252]
# I1120 19:00:56.045151 16648 undistortion.cc:215] Undistorting image [178/252]
# I1120 19:00:56.649158 16648 undistortion.cc:215] Undistorting image [179/252]
# I1120 19:00:58.752782 16648 undistortion.cc:215] Undistorting image [180/252]
# I1120 19:00:58.856094 16648 undistortion.cc:215] Undistorting image [181/252]
# I1120 19:00:59.416043 16648 undistortion.cc:215] Undistorting image [182/252]
# I1120 19:01:01.479818 16648 undistortion.cc:215] Undistorting image [183/252]
# I1120 19:01:01.479857 16648 undistortion.cc:215] Undistorting image [184/252]
# I1120 19:01:01.479867 16648 undistortion.cc:215] Undistorting image [185/252]
# I1120 19:01:03.141170 16648 undistortion.cc:215] Undistorting image [186/252]
# I1120 19:01:03.829192 16648 undistortion.cc:215] Undistorting image [187/252]
# I1120 19:01:05.856709 16648 undistortion.cc:215] Undistorting image [188/252]
# I1120 19:01:06.038954 16648 undistortion.cc:215] Undistorting image [189/252]
# I1120 19:01:06.496408 16648 undistortion.cc:215] Undistorting image [190/252]
# I1120 19:01:08.551630 16648 undistortion.cc:215] Undistorting image [191/252]
# I1120 19:01:08.815323 16648 undistortion.cc:215] Undistorting image [192/252]
# I1120 19:01:08.815366 16648 undistortion.cc:215] Undistorting image [193/252]
# I1120 19:01:10.199414 16648 undistortion.cc:215] Undistorting image [194/252]
# I1120 19:01:10.817744 16648 undistortion.cc:215] Undistorting image [195/252]
# I1120 19:01:13.103149 16648 undistortion.cc:215] Undistorting image [196/252]
# I1120 19:01:13.291517 16648 undistortion.cc:215] Undistorting image [197/252]
# I1120 19:01:13.747895 16648 undistortion.cc:215] Undistorting image [198/252]
# I1120 19:01:15.668828 16648 undistortion.cc:215] Undistorting image [199/252]
# I1120 19:01:15.950631 16648 undistortion.cc:215] Undistorting image [200/252]
# I1120 19:01:16.234241 16648 undistortion.cc:215] Undistorting image [201/252]
# I1120 19:01:17.634979 16648 undistortion.cc:215] Undistorting image [202/252]
# I1120 19:01:18.083564 16648 undistortion.cc:215] Undistorting image [203/252]
# I1120 19:01:20.014017 16648 undistortion.cc:215] Undistorting image [204/252]
# I1120 19:01:20.386698 16648 undistortion.cc:215] Undistorting image [205/252]
# I1120 19:01:20.694203 16648 undistortion.cc:215] Undistorting image [206/252]
# I1120 19:01:22.665947 16648 undistortion.cc:215] Undistorting image [207/252]
# I1120 19:01:22.807618 16648 undistortion.cc:215] Undistorting image [208/252]
# I1120 19:01:22.993106 16648 undistortion.cc:215] Undistorting image [209/252]
# I1120 19:01:24.535447 16648 undistortion.cc:215] Undistorting image [210/252]
# I1120 19:01:24.814535 16648 undistortion.cc:215] Undistorting image [211/252]
# I1120 19:01:27.282481 16648 undistortion.cc:215] Undistorting image [212/252]
# I1120 19:01:27.465538 16648 undistortion.cc:215] Undistorting image [213/252]
# I1120 19:01:28.143397 16648 undistortion.cc:215] Undistorting image [214/252]
# I1120 19:01:30.390798 16648 undistortion.cc:215] Undistorting image [215/252]
# I1120 19:01:30.390841 16648 undistortion.cc:215] Undistorting image [216/252]
# I1120 19:01:30.665313 16648 undistortion.cc:215] Undistorting image [217/252]
# I1120 19:01:32.056524 16648 undistortion.cc:215] Undistorting image [218/252]
# I1120 19:01:32.462877 16648 undistortion.cc:215] Undistorting image [219/252]
# I1120 19:01:34.724352 16648 undistortion.cc:215] Undistorting image [220/252]
# I1120 19:01:34.841612 16648 undistortion.cc:215] Undistorting image [221/252]
# I1120 19:01:35.212303 16648 undistortion.cc:215] Undistorting image [222/252]
# I1120 19:01:37.083371 16648 undistortion.cc:215] Undistorting image [223/252]
# I1120 19:01:37.442725 16648 undistortion.cc:215] Undistorting image [224/252]
# I1120 19:01:37.670425 16648 undistortion.cc:215] Undistorting image [225/252]
# I1120 19:01:39.006389 16648 undistortion.cc:215] Undistorting image [226/252]
# I1120 19:01:39.303808 16648 undistortion.cc:215] Undistorting image [227/252]
# I1120 19:01:42.190615 16648 undistortion.cc:215] Undistorting image [228/252]
# I1120 19:01:42.190656 16648 undistortion.cc:215] Undistorting image [229/252]
# I1120 19:01:42.612066 16648 undistortion.cc:215] Undistorting image [230/252]
# I1120 19:01:44.627075 16648 undistortion.cc:215] Undistorting image [231/252]
# I1120 19:01:44.820770 16648 undistortion.cc:215] Undistorting image [232/252]
# I1120 19:01:45.112267 16648 undistortion.cc:215] Undistorting image [233/252]
# I1120 19:01:46.217656 16648 undistortion.cc:215] Undistorting image [234/252]
# I1120 19:01:46.703877 16648 undistortion.cc:215] Undistorting image [235/252]
# I1120 19:01:49.777887 16648 undistortion.cc:215] Undistorting image [236/252]
# I1120 19:01:49.830184 16648 undistortion.cc:215] Undistorting image [237/252]
# I1120 19:01:49.830237 16648 undistortion.cc:215] Undistorting image [238/252]
# I1120 19:01:51.786409 16648 undistortion.cc:215] Undistorting image [239/252]
# I1120 19:01:51.786456 16648 undistortion.cc:215] Undistorting image [240/252]
# I1120 19:01:52.345934 16648 undistortion.cc:215] Undistorting image [241/252]
# I1120 19:01:53.372949 16648 undistortion.cc:215] Undistorting image [242/252]
# I1120 19:01:53.740093 16648 undistortion.cc:215] Undistorting image [243/252]
# I1120 19:01:57.122330 16648 undistortion.cc:215] Undistorting image [244/252]
# I1120 19:01:57.259516 16648 undistortion.cc:215] Undistorting image [245/252]
# I1120 19:01:57.259564 16648 undistortion.cc:215] Undistorting image [246/252]
# I1120 19:01:58.825646 16648 undistortion.cc:215] Undistorting image [247/252]
# I1120 19:01:58.877890 16648 undistortion.cc:215] Undistorting image [248/252]
# I1120 19:01:59.446388 16648 undistortion.cc:215] Undistorting image [249/252]
# I1120 19:02:00.119282 16648 undistortion.cc:215] Undistorting image [250/252]
# I1120 19:02:00.157573 16648 undistortion.cc:215] Undistorting image [251/252]
# I1120 19:02:02.731657 16648 undistortion.cc:215] Undistorting image [252/252]
# I1120 19:02:02.957619 16648 undistortion.cc:225] Writing reconstruction...
# I1120 19:02:03.973011 16648 undistortion.cc:230] Writing configuration...
# I1120 19:02:04.014787 16648 undistortion.cc:234] Writing scripts...
# I1120 19:02:04.028172 16648 timer.cc:91] Elapsed time: 3.907 [minutes]
# Done.

# %% [markdown]
# # Train the converted dataset

# %%
# %cd /content/drive/MyDrive/final_project_gsplat/gaussian-splatting
# !python train.py -s /content/drive/MyDrive/final_project_gsplat/gaussian-splatting/data/sv302 --iterations 60000 --save_iterations 7000 10000 25000 40000 60000----------  # --save_iterations: arg for saved checkpoints.
# Out:
# /content/drive/MyDrive/final_project_gsplat/gaussian-splatting
# 2024-11-20 19:11:11.243598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-20 19:11:11.266386: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-20 19:11:11.273015: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-20 19:11:11.288986: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-20 19:11:12.397969: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Optimizing
# Output folder: ./output/fd0b263f-6 [20/11 19:11:13]
# Reading camera 252/252 [20/11 19:11:15]
# Loading Training Cameras [20/11 19:11:15]
# [ INFO ] Encountered quite large input images (>1.6K pixels width), rescaling to 1.6K.
#  If this is not desired, please explicitly specify '--resolution/-r' as 1 [20/11 19:11:15]
# Loading Test Cameras [20/11 19:13:05]
# Number of points at initialisation :  57207 [20/11 19:13:05]
# Training progress:  12% 7000/60000 [15:52<2:13:25,  6.62it/s, Loss=0.0837469]
# [ITER 7000] Evaluating train: L1 0.04173730798065663 PSNR 24.313448333740237 [20/11 19:29:10]
#
# [ITER 7000] Saving Gaussians [20/11 19:29:10]
# Training progress:  17% 10000/60000 [24:20<2:25:50,  5.71it/s, Loss=0.0830598]
# [ITER 10000] Saving Gaussians [20/11 19:37:29]
# Training progress:  42% 25000/60000 [1:09:00<1:35:39,  6.10it/s, Loss=0.0553833]
# [ITER 25000] Saving Gaussians [20/11 20:22:09]
# Training progress:  50% 30000/60000 [1:22:54<1:21:51,  6.11it/s, Loss=0.0432187]
# [ITER 30000] Evaluating train: L1 0.01927381195127964 PSNR 30.17543296813965 [20/11 20:36:07]
# Training progress:  67% 40000/60000 [1:49:53<53:20,  6.25it/s, Loss=0.0323550]
# [ITER 40000] Saving Gaussians [20/11 21:03:03]
# Training progress: 100% 60000/60000 [2:43:16<00:00,  6.12it/s, Loss=0.0535018]
#
# [ITER 60000] Saving Gaussians [20/11 21:56:26]
#
# Training complete. [20/11 21:56:37]
